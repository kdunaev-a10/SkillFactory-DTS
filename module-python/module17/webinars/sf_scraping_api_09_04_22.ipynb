# %% [markdown]
# # Практикум по парсингу и работе с API

# %% [markdown]
# Булыгин Олег
#
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Telegram](https://t.me/obulygin91)
# * [Vk](vk.com/obulygin91)
# * email: obulygin91@ya.ru
#
# [Сообщество по Python](https://yandex.ru/q/loves/pythontalk/) на Кью
# [Сообщество по Data Science и анализу данных](https://yandex.ru/q/loves/datatalk/) на Кью

# %% [markdown]
# ## Поработаем с блогом SkillFactory

# %%
import pandas as pd
import requests

# %%
# метод get
res = requests.get('https://blog.skillfactory.ru/')
# res
res.status_code

# %%
# браузер отрисовал бы страницу на основе данного текста
res.text

# %%
# cформируем поисковый запрос, обратите внимание на его формат
URL = 'https://blog.skillfactory.ru/?s=python'

# %%
req = requests.get(URL)
req

# %%
req.text

# %%
# в request можно передать параметры запроса (для get), данные (для post) и заголовки (headers) в виде словарей. 
# сегодня не будем рассматривать примеры с необходимостью передачи заголовка, 
# но в практике вам это точно понадобится
URL = 'https://blog.skillfactory.ru/'
params = {
    's': 'python'
}

req = requests.get(URL, params=params)

req.text

# %%
# как разбирать всю эту разметку? Поможет BeautifulSoup.
# Документация: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
from bs4 import BeautifulSoup

# %%
# создаем объекта, через методы которого будем искать нужные теги и извлекать их содержимое
soup = BeautifulSoup(res.text)
soup

# %%
# функция finda_all позволяет найти все указанные тег с нужными атрибутами (с вложениями), возвращает список
news = soup.find_all('div', class_='post-card')
news

# %%
for el in news:
    # функция find ищет один указанный тег, возвращает именно его
    title = el.find('div', 'post-card__title').text # поле text позволяет извлечь текстовое содержимое тега
    print(title)
    link = el.find('a').get('href') # метод get позволяет извлечь значение атрибута
    print(link)
    category = el.find('span', 'post-card__category').text
    print(category)
    date = pd.to_datetime(el.find('meta', itemprop='datePublished').get('content'))
    print(date)
    print()

# %% [markdown]
# Напишем функцию на основе всех предыдущих действий, которая будет возвращать датафрейм с датой, заголовком, категорией и ссылкой на полный текст поста

# %%
def get_sf_blog_posts(url, query):
    params = {
        's': query
    }
    req = requests.get(url, params=params).text
    soup = BeautifulSoup(req)

    news = soup.find_all('div', class_='post-card')

    sf_blog = pd.DataFrame()

    for el in news:
        title = el.find('div', 'post-card__title').text
        link = el.find('a').get('href') 
        category = el.find('span', 'post-card__category').text
        date = pd.to_datetime(el.find('meta', itemprop='datePublished').get('content')) 
        row = {'date': date, 'title': title, 'link': link, 'category':category}
        sf_blog = pd.concat([sf_blog, pd.DataFrame([row])]) 
    return sf_blog.reset_index(drop=True)

get_sf_blog_posts('https://blog.skillfactory.ru/', 'python')

# %% [markdown]
# А как извлечь посты с нескольких страниц?

# %% [markdown]
# Для начала напишем функцию для определения количества страниц

# %%
def get_number_of_pages(url, query):
    params = {
        's': query
    }
    req = requests.get(url, params=params).text
    soup = BeautifulSoup(req)
    number_of_pages = int(soup.find_all('a', class_='page-numbers')[-2].text)
    return number_of_pages

print(get_number_of_pages('https://blog.skillfactory.ru/', 'python'))

# %%
import time

# %%
def get_sf_blog_posts(url, query, pages='all'):
    params = {
        's': query
    }

    if pages == 'all':
        number_of_pages = get_number_of_pages(url, query) # определяем количество страниц для конкретного запроса
        time.sleep(0.2)  # очень часто сайты могут ограничивать частые запросы к себе, поэтому нужно задерживать исполнение
    else:
        number_of_pages = pages

    
    sf_blog = pd.DataFrame()
    for page in range(1, number_of_pages+1):
        page_url = url + f'page/{page}/'
        print(page_url)
        req = requests.get(page_url, params=params).text
        time.sleep(0.3)
        soup = BeautifulSoup(req)

        news = soup.find_all('div', class_='post-card')


        for el in news:
            title = el.find('div', 'post-card__title').text
            # print(title)
            link = el.find('a').get('href') 
            category = el.find('span', 'post-card__category').text
            date = pd.to_datetime(el.find('meta', itemprop='datePublished').get('content')) # вот тут можем получить ошибку 
            row = {'date': date, 'title': title, 'link': link, 'category':category}
            sf_blog = pd.concat([sf_blog, pd.DataFrame([row])]) 

    return sf_blog.reset_index(drop=True)

get_sf_blog_posts('https://blog.skillfactory.ru/', 'python')

# %%
# исправим ситуацию с датой

def get_sf_blog_posts(url, query, pages='all'):
    params = {
        's': query
    }

    if pages == 'all':
        number_of_pages = get_number_of_pages(url, query) # определяем количество страниц для конкретного запроса
        time.sleep(0.2) 
    else:
        number_of_pages = pages
    
    sf_blog = pd.DataFrame()
    for page in range(1, number_of_pages+1):
        page_url = url + f'page/{page}/'
        # print(page_url)
        req = requests.get(page_url, params=params).text
        time.sleep(0.3)
        soup = BeautifulSoup(req)

        news = soup.find_all('div', class_='post-card')


        for el in news:
            title = el.find('div', 'post-card__title').text
            print(title)
            link = el.find('a').get('href') 
            category = el.find('span', 'post-card__category').text
            try:
                date = pd.to_datetime(el.find('meta', itemprop='datePublished').get('content')) 
            except:
                date = pd.NaT
            row = {'date': date, 'title': title, 'link': link, 'category':category}
            sf_blog = pd.concat([sf_blog, pd.DataFrame([row])]) 

    return sf_blog.reset_index(drop=True)

res = get_sf_blog_posts('https://blog.skillfactory.ru/', 'python')
res

# %% [markdown]
# А что если мы хотим еще получать полные тексты всех статей? Давайте напишем дополнительную функцию

# %%
# протестируем на двух страницах, чтобы долго не ждать

res = get_sf_blog_posts('https://blog.skillfactory.ru/', 'python', 2)
def add_full_text(posts_df):
    i = 0
    for el in posts_df['link']:
        # print(el)
        req = requests.get(el).text
        time.sleep(0.3)
        soup = BeautifulSoup(req)
        full_text = soup.find('div', class_='alignfull').text.strip() # опять получим ошибку
        posts_df.loc[i, 'text'] = full_text
        i += 1
    return posts_df

add_full_text(res)

# %%
res = get_sf_blog_posts('https://blog.skillfactory.ru/', 'python', 2)
def add_full_text(posts_df):
    i = 0
    for el in posts_df['link']:
        # print(el)
        req = requests.get(el).text
        time.sleep(0.3)
        soup = BeautifulSoup(req)
        try:
            full_text = soup.find('div', class_='alignfull').text.strip()
        except:
            full_text = soup.find('div', class_='left').text.strip()
        posts_df.loc[i, 'text'] = full_text
        i += 1
    return posts_df

add_full_text(res)

# %% [markdown]
# ## Примеры с API VK

# %%
token = '958eb5d439726565e9333aa30e50e0f937ee432e927f0dbd541c541887d919a7c56f95c04217915c32008'

# %% [markdown]
# Напишем функцию, которая будет находить группы по поисковому запросу при помощи метода [groups.search](https://vk.com/dev/groups.search)

# %%
def search_query(q, sorting=0):

    #Параметры sort
    #0 — сортировать по умолчанию (аналогично результатам поиска в полной версии сайта);
    #1 — сортировать по скорости роста;
    #2 — сортировать по отношению дневной посещаемости к количеству пользователей;
    #3 — сортировать по отношению количества лайков к количеству пользователей;
    #4 — сортировать по отношению количества комментариев к количеству пользователей;
    #5 — сортировать по отношению количества записей в обсуждениях к количеству пользователей.
    params = {
        'q': q,
        'access_token': token,
        'v':'5.131',
        'sort': sorting,
        'count': 300
    }
    req = requests.get('https://api.vk.com/method/groups.search', params).json()
    # print(req)
    req = req['response']['items']
    return req

# search_query('python', 0)
res_df = pd.DataFrame(search_query('python', 0))
res_df

# %% [markdown]
# Получим расширенную информацию по группам при помощи метода [groups.getById](https://vk.com/dev/groups.getById)

# %%
# преобразуем список всех id в строку (в таком виде принимает данные параметр fields)
groups_ids = ','.join(str(x) for x in res_df.id)
groups_ids

# %%
# преобразуем список всех id в строку (в таком виде принимает данные параметр fields)

params = {
    'access_token': token,
    'v':'5.131',
    'group_ids': groups_ids,
    'fields':  'members_count,activity,description'

}
req = requests.get('https://api.vk.com/method/groups.getById', params)
# req

# print(req)

pd.DataFrame(req.json()['response']).sort_values('members_count', ascending=False)

# %% [markdown]
# Напишем программу, которая будет искать посты в новостной ленте по указанным запросам при помощи [newsfeed.search](https://vk.com/dev/newsfeed.search)

# %%
def get_newsfeed_posts(url, tag):
    newsfeed_df = pd.DataFrame()
    params = {
        'access_token': token,
        'v':'5.131',
        'q': tag,
        'count': 200,
        'extended': 1
    }    
    while True:
        result = requests.get(url, params)
        time.sleep(0.33)
        newsfeed_df = pd.concat([newsfeed_df, pd.DataFrame(result.json()['response']['items'])])
        if 'next_from' in result.json()['response'].keys():
            params['start_from'] = result.json()['response']['next_from']
        else:
            break
    return newsfeed_df


def main_vk_newsfeed():
    print('Собираем данные из новостной ленты ВК')
    tag_list = ['skillfactory']
    url = 'https://api.vk.com/method/newsfeed.search'
    df = pd.DataFrame()
    for tag in tag_list:
        df = pd.concat([df, get_newsfeed_posts(url, tag)])
    print('Собрали данные из новостной ленты ВК')
    return df

main_vk_newsfeed()

# %% [markdown]
# ## Напишем скрипт, который будет собирать новости с сайта Коммерсанта

# %%
URL = 'https://www.kommersant.ru/search/results'
params = {
    'search_query': 'python'
}

# %%
res = requests.get(URL, params)

# %%
res.text
# Out:
# '<!DOCTYPE html>\r\n<html class="no-js" lang="ru">\r\n<head>\r\n    <title>Коммерсантъ: последние новости России и мира</title>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1" />\r\n    <meta charset="utf-8" />\r\n\r\n    <meta name="format-detection" content="telephone=no" />\r\n    <meta name="title" content="Коммерсантъ: последние новости России и мира" />\r\n    <meta name="description" content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" />\r\n    <meta name="keywords" content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" />\r\n\r\n    <meta name="yandex-verification" content="50df68945a519dbd" />\r\n\r\n    \r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n\r\n\r\n\r\n        <meta property="fb:app_id" content="324580610921010" />\r\n        <meta property="og:type" content="website" />\r\n        <meta property="og:url" content="https://www.kommersant.ru" />\r\n        <meta property="og:title" content="Коммерсантъ: последние новости России и мира" />\r\n        <meta property="og:description" content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" />\r\n        <meta property="og:image" content="https://im.kommersant.ru/ContentFlex/images/logo.png" />\r\n        <link rel="image_src" href="https://im.kommersant.ru/CorpPics/logo200.jpg" />\r\n\r\n    \r\n<!-- common css -->\r\n    <script>\r\n        document.documentElement.classList.remove(\'no-js\');\r\n    </script>\r\n\r\n    <link rel="preconnect" href="https://use.typekit.net/" crossorigin>\r\n    <link rel="preload" as="style" href="https://use.typekit.net/mfw2heq.css">\r\n    <link rel="stylesheet" media="print" onload="this.onload=null;this.removeAttribute(\'media\');" href="https://use.typekit.net/mfw2heq.css">\r\n    <noscript>\r\n        <link rel="stylesheet" href="https://use.typekit.net/mfw2heq.css">\r\n    </noscript>\r\n\r\n    <link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonCss.css?2204071948420000" rel="stylesheet">\r\n    <link rel="preload" href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2204071948420000" as="style" onload="this.onload=null;this.rel=\'stylesheet\'">\r\n    <noscript><link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2204071948420000"></noscript>\r\n<!-- common css end -->\r\n\r\n\r\n    \r\n\r\n    \r\n<link rel="apple-touch-icon" sizes="57x57" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-57.png">\r\n<link rel="apple-touch-icon" sizes="60x60" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-60.png">\r\n<link rel="apple-touch-icon" sizes="72x72" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-72.png">\r\n<link rel="apple-touch-icon" sizes="76x76" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-76.png">\r\n<link rel="apple-touch-icon" sizes="114x114" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-114.png">\r\n<link rel="apple-touch-icon" sizes="120x120" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-120.png">\r\n<link rel="apple-touch-icon" sizes="144x144" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-144.png">\r\n<link rel="apple-touch-icon" sizes="152x152" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-152.png">\r\n<link rel="apple-touch-icon" sizes="180x180" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-180.png">\r\n<link rel="icon" type="i ...

# %%
soup = BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="ru">
# <head>
# <title>Коммерсантъ: последние новости России и мира</title>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Коммерсантъ: последние новости России и мира" name="title"/>
# <meta content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" name="description"/>
# <meta content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" name="keywords"/>
# <meta content="50df68945a519dbd" name="yandex-verification"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="324580610921010" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.kommersant.ru" property="og:url"/>
# <meta content="Коммерсантъ: последние новости России и мира" property="og:title"/>
# <meta content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" property="og:description"/>
# <meta content="https://im.kommersant.ru/ContentFlex/images/logo.png" property="og:image"/>
# <link href="https://im.kommersant.ru/CorpPics/logo200.jpg" rel="image_src"/>
# <!-- common css -->
# <script>
#         document.documentElement.classList.remove('no-js');
#     </script>
# <link crossorigin="" href="https://use.typekit.net/" rel="preconnect"/>
# <link as="style" href="https://use.typekit.net/mfw2heq.css" rel="preload"/>
# <link href="https://use.typekit.net/mfw2heq.css" media="print" onload="this.onload=null;this.removeAttribute('media');" rel="stylesheet"/>
# <noscript>
# <link href="https://use.typekit.net/mfw2heq.css" rel="stylesheet"/>
# </noscript>
# <link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonCss.css?2204071948420000" rel="stylesheet"/>
# <link as="style" href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2204071948420000" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonDeferCss.css?2204071948420000" rel="stylesheet"/></noscript>
# <!-- common css end -->
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/apple-touch-icon-180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/android-chrome-192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons2020/favicon-16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="https://im.kommersant.ru/ContentFlex/images/favicons2020/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#2d89ef" name="msapplication-TileColor"/>
# <meta content="https://im.kommersant.ru/ContentFlex/images/favicons2020/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- search page head css -->
# <link href="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.search.css?2204071948420000" rel="stylesheet"/>
# <!-- search page head css end -->
# <script>
#                 window.puids = {
#                     'puid1': '0',
#                     'puid2': '',
#                     'puid3': '',
#                     'puid4': 'i0',
#                     'puid5': '999'
#                 };
#     </script>
# <!-- common scripts -->
# <link href="https://im.kommersant.ru" rel="preconnect"/>
# <script src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonJS.js?2204071948420000"></script>
# <script async="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.pushPopup.js?2204071948420000"></script>
# <script defer="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.pollJS.js?2204071948420000"></script>
# <script>
#     kommersant.antiCache.jsMark = 'https://im.kommersant.ru/ContentFlex/js/jquery.mark.min.js?2109231134459908';
#     kommersant.antiCache.jsJqueryValidate = 'https://im.kommersant.ru/ContentFlex/js/jquery.validate.min.js?2109231134459908';
#     kommersant.antiCache.jsNanoScroller = 'https://im.kommersant.ru/ContentFlex/js/jquery.nanoscroller.min.js?2109231134459908';
#     kommersant.antiCache.jsScrollMagic = 'https://im.kommersant.ru/ContentFlex/js/scrollmagic/ScrollMagic.min.js?2109231134459908';
#     kommersant.antiCache.jsHighmapsCisDisputed = 'https://im.kommersant.ru/ContentFlex/js/highmaps/cis-disputed.js?2109231134459908';
#     kommersant.antiCache.jsCharts = 'https://im.kommersant.ru/ContentFlex/js/charts.new2021.js?2202141653190991';
#     kommersant.antiCache.jsWidgets = 'https://im.kommersant.ru/ContentFlex/js/widgets.new2021.js?2201111747301991';
#     kommersant.antiCache.jsHighmapsWorldDisputed = 'https://im.kommersant.ru/ContentFlex/js/highmaps/world-disputed.js?2109231134459908';
#     kommersant.vicons.add('https://im.kommersant.ru/ContentFlex/ajax/vicons/common.new2021.html?2110202128418612', { cache: true });
#
# </script>
# <script>
#     window.__storage__ = window.__storage__ || {}
#     window.__storage__.lentaBanners = {
#         businessAnnounce: "&lt;!--AdFox START--&gt; &lt;!--kommersant--&gt; &lt;!--Площадка: Kommersant_redesign / 0Десктоп / 3й анонс в ленте--&gt; &lt;!--Категория: &lt;не задана&gt;--&gt; &lt;!--Тип баннера: 3й анонс в ленте--&gt; &lt;!--197--&gt;  &lt;div id=&quot;adfox_162799247887971226&quot;&gt;&lt;/div&gt; &lt;script&gt;     window.yaContextCb.push(()=&gt;{         Ya.adfoxCode.create({             ownerId: 1092,         containerId: &#39;adfox_162799247887971226&#39;,             params: Object.assign({                 p1: &#39;cqgxq&#39;,             p2: &#39;hhrr&#39;,          }, window.puids || {})        }, [&#39;desktop&#39;,&#39;phone&#39;,&#39;tablet&#39;], {         tabletWidth: 1197.99,         phoneWidth: 1197.99,         isAutoReloads: false     })   })  &lt;/script&gt; ",
#         twoAnnounces: [{"Id":562,"ProfileId":1,"Position":1,"Type":1,"DocId":5295689,"Title":"BELUGA GROUP объявляет операционные результаты за I квартал 2022 года","Subtitle":"Компания фиксирует рекордные продажи","Link":null,"IsSelfLink":false,"ImageSrc":"https://im.kommersant.ru/Issues.photo/Partners_Docs/2022/04/07/KMO_111307_42585_1_t218_183728.jpg","Enabled":true,"Category":"Промо"},{"Id":559,"ProfileId":1,"Position":2,"Type":1,"DocId":5230850,"Title":"Офис с интеллектом в «Москва-Сити»","Subtitle":"Компания MR Group ведет строительство деловых небоскребов iCITY","Link":null,"IsSelfLink":false,"ImageSrc":"https://im.kommersant.ru/Issues.photo/Partners_Docs/2022/02/25/KMO_111307_42045_1_t218_142639.jpg","Enabled":true,"Category":"Промо"}]
#     }
# </script>
# <script async="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.lentaVue.js?2204071948420000"></script>
# <!-- common scripts end-->
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
#         window.kommersant.backend.adv = {
#             180: '\u003c!--AdFox START--\u003e\r\n\u003c!--kommersant--\u003e\r\n\u003c!--Площадка: Kommersant_redesign / 0Десктоп / БА2--\u003e\r\n\u003c!--Категория: \u003cне задана\u003e--\u003e\r\n\u003c!--Тип баннера: СБА_БА--\u003e\r\n\u003c!--180--\u003e\r\n\u003cdiv id=\"adfox_161707797679975629\"\u003e\u003c/div\u003e\r\n\u003cscript\u003e\r\n    window.yaContextCb.push(()=\u003e{\r\n        Ya.adfoxCode.createScroll({\r\n        ownerId: 1092,\r\n        containerId: \u0027adfox_161707797679975629\u0027,\r\n        params: Object.assign({\r\n            p1: \u0027corsv\u0027,\r\n            p2: \u0027hedx\u0027,\r\n           }, window.puids || {})\r\n       }, [\u0027desktop\u0027], {\r\n        tabletWidth: 1197.99,\r\n        phoneWidth: 1197.99,\r\n        isAutoReloads: false\r\n     })\r\n  })\r\n\u003c/script\u003e',
#         };
#     </script>
# </head>
# <body>
# <svg aria-hidden="true" style="display: none" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><symbol id="vicon-main_logo" viewbox="0 0 158 20"><path d="M40 4h5v12h-4V9l-2.8 7h-1.9c-.2-.7-.5-.6-2.3-7v7h-4V4h5.5l1.8 6.6L40 4zm13.3 6.6L51.5 4H46v12h4V9c1.8 6.4 2 6.3 2.3 7h2c0-.3 2.6-6.6 2.7-7v7h4V4h-5l-2.7 6.6zM15.7 0H10L5 5.6V0H0v16h5v-5.1l1.5-1.6 4 6.7h6L9.8 6l5.8-6zM29 10c0 4-2.5 6.3-6.6 6.3-4 0-6.5-2.3-6.5-6 0-3.9 2.4-6.2 6.5-6.2 4 0 6.6 2.4 6.6 6zm-4.3 0c0-1.8-1-3.1-2.2-3.1-1.7 0-2.3 1.6-2.3 3.2 0 3 1.4 3.4 2.2 3.4 1 0 2.3-.6 2.3-3.4zM158 12c0 3-2.7 4-5 4h-7V7h-3V4h7v4h3c3.5 0 5 2.1 5 4zm-4 0c0-1.2-1.1-1.4-2.1-1.4h-1.7v2.7h1.7c1 0 2.1-.1 2.1-1.3zm-24-5h4v9h4V7h4V4h-12v3zm-14 7.5c0 .6 0 1 .6 1.5h-4.7l-.2-1.5-.3.2a5.8 5.8 0 01-4.3 1.6c-2 0-4-.9-4-3.4 0-3.1 3-3.5 5.3-3.8 1.7-.2 3-.3 3-1.4 0-.7-.6-1.2-1.7-1.2-1 0-1.6.4-1.8 1.2h-4.2c.2-2.4 2.2-3.6 6.3-3.6 5.4 0 6 2 6 4.8v5.6zm-4.5-4l-.3.2a7 7 0 01-1.6.5c-1.1.2-2.1.4-2.1 1.6 0 .7.7 1.2 1.7 1.2 2 0 2.3-1.6 2.3-3.1v-.3zM125 9h-4V4h-4v12h4v-4h4v4h4V4h-4v5zm-36 1.1c0 4.6-2.4 5.9-5 5.9a5 5 0 01-2-.5c-.3-.2-1-.5-1.6-1.1L80 14v6h-4V4h4v2c.6-1.4 2.6-1.9 3.9-1.9 3.7 0 5 3.2 5 6zm-4.3 0c0-1.8-.9-3-2.3-3-1.3 0-2.1 1.3-2.1 3 0 1.8.8 3 2.1 3 1.4 0 2.3-1.2 2.3-3zm-18.4.9v.3c0 1.4 1.1 2.5 2.6 2.5a2 2 0 001.7-.8h4.2c-1.2 3-4.7 3.3-6.2 3.3-4 0-6.6-2.4-6.6-6s2.7-6.2 6.5-6.2c4.2 0 6.8 2.6 6.8 6.9h-9zm0-2H71V9c0-1.3-1-2.3-2.3-2.3-1.5 0-2.4.9-2.4 2.3V9zM96 13.6c-1.4 0-2.3-1.1-2.3-3.2C93.7 7.5 95 7 96 7c1 0 1.8.7 2 1.7h4.3C101.9 5.8 99.6 4 96 4c-4 0-6.6 2.4-6.6 6.2 0 3.6 2.6 6 6.6 6 2.1 0 5.6-.6 6.3-4.3H98c-.3 1-1 1.5-2 1.5z"></path></symbol><symbol id="vicon-search" viewbox="0 0 30 30"><path d="M24.55 22.97l-5-5.01a8.09 8.09 0 10-1.58 1.58l5 5.02c.53.52 1.3.6 1.74.15s.37-1.21-.16-1.74zM13.1 18.68a5.6 5.6 0 110-11.2 5.6 5.6 0 010 11.2z"></path></symbol><symbol id="vicon-burger" viewbox="0 0 30 30"><path d="M25 6v4H5V6h20zM5 17h20v-4H5v4zm0 7h20v-4H5v4z"></path></symbol><symbol id="vicon-regions" viewbox="0 0 30 30"><path d="M15.1 5C19 5 22 8 22 11.9c0 4.3-6.9 13.1-6.9 13.1s-6.8-8.7-6.8-13.1C8.3 8 11.3 5 15 5zm0 10a3.1 3.1 0 100-6.2 3.1 3.1 0 000 6.2z"></path></symbol><symbol id="vicon-fm" viewbox="0 0 30 30"><path d="M24.25 16.21L20 18.34v-6.68l4.25 2.13c1 .5 1 1.92 0 2.42zm-9.7-4.96l1.2 4.56 1.18-4.56h2.24l-12.2-6.1C6.05 4.68 5 5.34 5 6.34v4.9h5.8v1.61H7.34v1.31h2.94v1.52H7.35v3.06H5v4.9c0 1 1.06 1.66 1.96 1.2l12.21-6.1H18.1v-5.72l-1.49 5.72h-1.73l-1.48-5.72v5.72h-1.92v-7.5h3.08z"></path></symbol><symbol id="vicon-rarrow" viewbox=" 0 0 30 30"><path d="M9.22.33c.85-.59 2.02-.38 2.61.47l9.38 13.48c.45.66.44 1.54-.03 2.18l-9.37 12.77a1.87 1.87 0 11-3.03-2.22L17.36 15 8.76 2.94a1.88 1.88 0 01.46-2.6z"></path></symbol></svg>
# <div id="counters-top" style="position: absolute; visibility: hidden">
# <script>
# (function () {
#   window.kommersantAnalytics = {
#     adblock: '',
#     rubrics: '',
#     publishing: '',
#     themes: '',
#     themegroups: '',
#     authors: '',
#     audio: 'No',
#     liveinternet: ''
#   };
#   var advad = new Image();
#   advad.onload = function () {
#     window.kommersantAnalytics.adblock = 'No';
#   };
#   advad.onerror = function () {
#     window.kommersantAnalytics.adblock = 'Yes';
#   };
#   advad.src = 'https://im.kommersant.ru/ContentFlex/images/adv.gif';
# })();
# </script>
# <!-- Kommersant -->
# <script>
# function counterKommersant() {
# //new Image().src = '//www.kommersant.ru/headerfooter/counterA?p=0&ref=' + escape(document.referrer) + '&rnd=' + Math.floor(Math.random() * 1000000000);
# }
# function counterKommersantRead() {
#
# }
# counterKommersant();
# counterKommersantRead();
# </script>
# <noscript>
# </noscript>
# <!-- /Kommersant -->
# <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "84394", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
# if (d.getElementById(id)) return;
# var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
# ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
# var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
# if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="" src="//top-fwz1.mail.ru/counter?id=84394;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!--LiveInternet counter-->
# <script>
# function counterLiveInternet() {
#   new Image().src = "//counter.yadro.ru/hit" + (window.kommersantAnalytics.liveinternet ? ";" + window.kommersantAnalytics.liveinternet : "") + "?r" + escape(document.referrer) + ((typeof (screen) == "undefined") ? "" : ";s" + screen.width + "*" + screen.height + "*" + (screen.colorDepth ? screen.colorDepth : screen.pixelDepth)) + ";u" + escape(document.URL) + ";h" + escape(document.title.substring(0, 80)) + ";" + Math.random();
# }
# counterLiveInternet();
# </script>
# <noscript>
# <img alt="" height="1" src="//counter.yadro.ru/hit" width="1"/>
# </noscript>
# <!--/LiveInternet-->
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#   var yaParams = {
#
# };
# </script>
# <script type="text/javascript">
#   (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#   m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#   (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#   ym(153166, "init", {
#     clickmap:true,
#     trackLinks:true,
#     accurateTrackBounce:true,
#     trackHash:true,
#     params: yaParams
#   });
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/153166" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <img id="advad" src="https://im.kommersant.ru/ContentFlex/images/adv.gif" style="display: none"/>
# <script>
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date(); a = s.createElement(o),
# m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-875277-5', 'kommersant.ru');
#
# ga('set', 'dimension6', 'No');
# if (window.kommersantAnalytics.adblock) {
#   ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# }
# ga('set', 'page', window.location.pathname + window.location.search + window.location.hash);
# ga('send', 'pageview');
# </script>
# <!-- tns-counter.ru -->
# <script>
# function counterTnsNew() {
#   try {
#     fetch('//tns-counter.ru/e/ec01&cid=kommersant_ru&typ=1&tms=kommersant_ru&idc=155', { credentials: 'include' });
#   } catch (ignore) {}
# }
# counterTnsNew();
# </script>
# <noscript>
# <img alt="" height="1" src="//tns-counter.ru/e/ec01&amp;cid=kommersant_ru&amp;typ=1&amp;tms=kommersant_ru&amp;idc=155" width="1"/>
# </noscript>
# <!--/tns-counter.ru -->
# <!-- tns-counter.ru -->
# <script>
# function counterTnsOld() {
#   new Image().src = '//tns-counter.ru/V13a***R>' + document.referrer.replace(/\*/g, '%2a') + '*kommersant_ru/ru/CP1251/tmsec=komm_junk/' + Math.floor(Math.random() * 900000000 + 100000000);
# }
# counterTnsOld();
# </script>
# <noscript>
# <img alt="" height="1" src="//tns-counter.ru/V13a****kommersant_ru/ru/CP1251/tmsec=komm_junk/" width="1"/>
# </noscript>
# <!--/tns-counter.ru -->
# </div>
# <script>
# function countersUpdate() {
#   counterKommersant();
#   counterKommersantRead();
#
#   try {
#     _tmr.push({id: '84394', type: 'pageView', url: document.URL, start: (new Date()).getTime()});
#   } catch (ignore) {}
#
#   counterLiveInternet();
#
#   (function () {
#     var yaParams = {};
#     window.kommersantAnalytics.rubrics && (yaParams.rubric = window.kommersantAnalytics.rubrics);
#     window.kommersantAnalytics.publishing && (yaParams.publication = window.kommersantAnalytics.publishing);
#     window.kommersantAnalytics.themes && (yaParams.theme = window.kommersantAnalytics.themes);
#     window.kommersantAnalytics.themegroups && (yaParams.maintheme = window.kommersantAnalytics.themegroups);
#     try {
#       ym(153166, 'params', yaParams);
#       ym(153166, 'hit', window.location.pathname + window.location.search + window.location.hash, {
#         params: yaParams
#       });
#     } catch (ignore) {}
#   })();
#
#   (function () {
#     try {
#       ga('set', 'page', window.location.pathname + window.location.search + window.location.hash);
#       ga('set', 'dimension1', window.kommersantAnalytics.rubrics || null);
#       ga('set', 'dimension2', window.kommersantAnalytics.publishing || null);
#       ga('set', 'dimension4', window.kommersantAnalytics.themes || null);
#       ga('set', 'dimension5', window.kommersantAnalytics.themegroups || null);
#       ga('set', 'dimension8', window.kommersantAnalytics.authors || null);
#       ga('set', 'dimension6', window.kommersantAnalytics.audio || null);
#       ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
#       ga('send', 'pageview');
#     } catch (ignore) {}
#   })();
#
#   counterTnsNew();
#
#   counterTnsOld();
#
#
# }
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / Fullscreen-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <!--190-->
# <div id="adfox_160803209609717001"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_160803209609717001',
#         params: Object.assign({
#             p1: 'blnry',
#             p2: 'eurl'
#           }, window.puids || {})
#        }, ['desktop','phone','tablet'], {
#         tabletWidth: 1197.99,
#         phoneWidth: 1197.99,
#         isAutoReloads: false
#     })
#   })
#
# </script><!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / 0Десктоп / BackGround test-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BackGround-->
# <!--185-->
# <div id="adfox_153864371043563488"></div>
# <script>
#
# window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#
#         ownerId: 1092,
#         containerId: 'adfox_153864371043563488',
#         params: Object.assign({
#             p1: 'cbuhy',
#             p2: 'gbom',
#           }, window.puids || {}),
#          onRender: function () {$('.adfox-banner-background').after('<style>.adv3-2_140pxx1200px {display: none;}@media only screen and (min-width: 1200px) {body {padding-top: 250px;}.main_nav {max-width: 1180px;width: 100%;margin-left: auto;margin-right: auto;}.bg_cover {position: absolute;top: 250px;right: 0;left: 0;bottom: 0;background-color: #fff;width: 1180px;margin: 0 auto;}}</style><div class="bg_cover"></div>')}
#
#        }, ['desktop'], {
#           tabletWidth: 1197.99,
#           phoneWidth: 1197.99,
#       })
#   })
# </script> <input aria-hidden="true" aria-labeledby="site_menu" class="hide site_menu_trigger" hidden="" id="burger_trigger" type="checkbox"/>
# <div class="layout">
# <div class="adv_nest adv_nest--980x250_top hide_mobile">
# <div class="adv_dummy"><a href="/ad" target="_blank">Реклама в «Ъ» www.kommersant.ru/ad</a></div>
# <div class="adv_980x240">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign / 0Десктоп / BILB I (970_250) Перетяжка-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BILBI_970_250-->
# <!--167-->
# <div id="adfox_160803211171647429"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_160803211171647429',
#         params: Object.assign({
#             p1: 'blnrl',
#             p2: 'eurc',
#             pk: 'оккупация%20украин%20донецк%20луганск%20бомб%20санкци%20днр%20лнр%20Донбасс%20военная',
#             pke: '1'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 1197.99,
#         phoneWidth: 1197.99,
#         isAutoReloads: false
#      })
#   })
#
# </script>
# </div>
# </div>
# <div class="adv_nest adv_nest--300x250_top hide_desktop">
# <div class="adv_dummy"><a href="/ad" target="_blank">Реклама в «Ъ» www.kommersant.ru/ad</a></div>
# <div class="adv_300x250_top">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / BILB 300x250 I-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 300x250-->
# <!--173-->
# <div id="adfox_1488194504651863"></div>
# <script>
#      window.yaContextCb.push(()=>{
#         Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1488194504651863',
#
#         params: Object.assign({
#             p1: 'bukwz',
#              p2: 'fibq',
#             pk: 'оккупация%20украин%20донецк%20луганск%20бомб%20санкци%20днр%20лнр%20Донбасс%20военная',
#             pke: '1'
#         }, window.puids || {})
#     }, ['phone','tablet'], {
#         tabletWidth: 1197.99,
#         phoneWidth: 1197.99,
#         isAutoReloads: false
#      })
#   })
#
# </script>
# </div>
# </div>
# </div>
# <header class="main_header">
# <div class="layout">
# <div class="main_header__content">
# <label class="main_header__item main_header__burger" for="burger_trigger" tabindex="0" title="Рубрики и разделы">
# <!-- <img src="i/burger.png" class="main_header__icon" alt="Рубрики и разделы"> -->
# <span class="vicon vicon--burger main_header__icon main_header__burger_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-burger" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="main_header__logo" href="/?from=logo">
# <svg aria-hidden="true" class="main_header__logo_img"><use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="vh">Коммерсантъ</span>
# </a>
# <div class="main_header__buttons">
# <span class="auth js-auth main_header__item hide_mobile">
# <a class="auth__profile" href="/lk/profile?from=header" title="Профиль">
# <span aria-hidden="true" class="vicon main_header__icon main_header__login_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-user" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="auth__login user-login" href="/LK/Login?from=header" title="Личный кабинет">
# <span aria-hidden="true" class="vicon main_header__icon main_header__login_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-enter" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </span>
# <a class="main_header__item main_header__item--regions hide_mobile js-navmenu-trigger" data-navmenu-class-active="main_header__item--active" data-navmenu-id="js-navmenu-regions" href="/regions" title="Регионы">
# <span class="main_header__pointer"></span>
# <span aria-hidden="true" class="vicon main_header__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-regions" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="ui-button main_header__item main_header__item--fm hide_mobile fm_announce" href="/fm/player?from=header" rel="nofollow" target="_blanc" title="Коммерсантъ FM">
# <span class="vh">Коммерсантъ FM</span>
# <span aria-hidden="true" class="vicon main_header__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-fm" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <form action="/search/results" class="main_header__item main_header__item--search" id="js-navsearch-form" method="get">
# <input name="places" type="hidden" value=""/>
# <input name="categories" type="hidden" value=""/>
# <input name="datestart" type="hidden" value="2021-04-09"/>
# <input name="dateend" type="hidden" value="2022-04-09"/>
# <input name="sort_type" type="hidden" value="1"/>
# <input name="regions" type="hidden" value=""/>
# <input name="results_count" type="hidden" value=""/>
# <input name="page" type="hidden" value="1"/>
# <input class="main_header__search_field" id="js-navsearch-query" name="search_query" placeholder="Поиск" type="search"/>
# <button class="ui-button vicon main_header__icon" id="js-navsearch-submit" title="Поиск" type="submit">
# <svg class="vicon__body">
# <use xlink:href="#vicon-search" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </button>
# </form>
# </div>
# </div>
# </div>
# </header>
# <section class="site_menu hide_while_loading" id="site_menu" itemscope="" itemtype="https://www.schema.org/SiteNavigationElement">
# <label class="site_menu__close_overlay" for="burger_trigger"><span class="vh">Закрыть меню</span></label>
# <div class="site_menu__lift">
# <div class="layout site_menu__body">
# <h4 class="site_menu__name vh" id="site_menu__name">
#                 Меню сайта
#             </h4>
# <div class="site_menu__header">
# <label class="site_menu__header_item site_menu__burger" for="burger_trigger" tabindex="0" title="Рубрики и разделы">
# <span class="vicon site_menu__icon site_menu__burger_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-burger" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="site_menu__logo" href="/?from=logo">
# <svg class="site_menu__logo_img"><use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </a>
# <label class="site_menu__header_item site_menu__close" for="burger_trigger" tabindex="0">
# <span class="site_menu__close_text">Закрыть</span>
# <span aria-hidden="true" class="vicon vicon--close site_menu__icon site_menu__close_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# </div>
# <div class="auth js-auth site_menu__list site_menu__list--big site_menu__list--auth hide_desktop">
# <a class="auth__profile" href="/lk/profile?from=burger" title="Профиль">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-user" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="auth__login user-login" href="/LK/Login?from=burger" title="Личный кабинет">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-enter" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="hide_desktop" data-navmenu-class-active="main_header__item--active" data-navmenu-id="js-navmenu-regions" href="/regions" title="Регионы">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-regions" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="hide_desktop" href="/fm/player?from=burger" rel="nofollow" target="_blanc" title="Коммерсантъ FM">
# <span aria-hidden="true" class="vicon site_menu__auth_icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-fm" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </div>
# <ul class="site_menu__list site_menu__list--big">
# <li class="site_menu__item site_menu__item--big" itemprop="name">
# <a href="/redaction?from=burger" itemprop="url">Редакция</a>
# </li>
# <li class="site_menu__item site_menu__item--big" itemprop="name">
# <a href="/fm?from=burger" itemprop="url">Радио «Ъ FM»</a>
# </li>
# <li class="site_menu__item site_menu__item--big" itemprop="name">
# <a href="//rusfond.ru?from=burger" itemprop="url" target="_blank">Русфонд</a>
# <a href="//rusfond.ru?from=burger" target="_blank"><img alt="Русфонд" class="site_menu__rusfond_img" src="https://im.kommersant.ru/ContentFlex/images/redesign2020/rusfond_logo.png"/></a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="//bankruptcy.kommersant.ru?from=burger" itemprop="url" target="_blank">Банкротства</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/partnerprojects?from=burger" itemprop="url">Партнерские проекты</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="//www.kartoteka.ru?from=burger" itemprop="url" target="_blank">Картотека</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="//events.kommersant.ru?from=burger" itemprop="url" target="_blank">Конференции</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="//university.kommersant.ru?from=burger" itemprop="url" target="_blank">Университетъ</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/subscription?from=burger" itemprop="url">Подписка</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/ad?from=burger" itemprop="url">Реклама</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="https://photo.kommersant.ru/?from=burger" itemprop="url">Фотоагентство</a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="/daily?from=burger" itemprop="url">Газета</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/weekend?from=burger" itemprop="url">Weekend</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/apps?from=burger" itemprop="url">Приложения</a>
# </li>
# <li class="site_menu__item site" itemprop="name">
# <a href="/autopilot?from=burger" itemprop="url">Автопилот</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/nauka?from=burger" itemprop="url">Наука</a>
# </li>
# <li class="site_menu__item site_menu__item--indent" itemprop="name">
# <a href="/money?from=burger" itemprop="url">Деньги</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/regions?from=burger" itemprop="url">Регионы</a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/3?from=burger" itemprop="url">Экономика</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/2?from=burger" itemprop="url">Политика</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/5?from=burger" itemprop="url">Мир</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/4?from=burger" itemprop="url">Бизнес</a>
# </li>
# <li class="site_menu__item site" itemprop="name">
# <a href="/finance?from=burger" itemprop="url">Финансы</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/41?from=burger" itemprop="url">Потребительский рынок</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/138?from=burger" itemprop="url">Телекоммуникации</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/7?from=burger" itemprop="url">Общество</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/6?from=burger" itemprop="url">Происшествия</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/8?from=burger" itemprop="url">Культура</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/rubric/9?from=burger" itemprop="url">Спорт</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/hitech?from=burger" itemprop="url">Hi-Tech</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/auto?from=burger" itemprop="url">Авто</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/style?from=burger" itemprop="url">Стиль</a>
# </li>
# </ul>
# <ul class="site_menu__list">
# <li class="site_menu__item" itemprop="name">
# <a href="/themes?from=burger" itemprop="url">Темы</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/theme/3155?from=burger" itemprop="url">Тенденции</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/specials?from=burger" itemprop="url">Мультимедиа</a>
# </li>
# <li class="site_menu__item site" itemprop="name">
# <a href="/theme/2590?from=burger" itemprop="url">Интервью</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/doc/3688126?from=burger" itemprop="url">Справочники</a>
# </li>
# <li class="site_menu__item site_menu__item--indent" itemprop="name">
# <a href="/ratings?from=burger" itemprop="url">Самое читаемое</a>
# </li>
# <li class="site_menu__item" itemprop="name">
# <a href="/lk/notification?from=burger" itemprop="url">E-mail рассылки</a>
# </li>
# </ul>
# </div>
# </div>
# </section>
# <div class="regions hide_while_loading hide_mobile">
# <div class="regions__menu js-navmenu-item" data-navmenu-class-active="regions__menu--active" id="js-navmenu-regions">
# <div class="layout">
# <div class="main">
# <div class="regions__body">
# <ul class="regions__list">
# <li class="regions__item">
# <a class="regions__link" href="/theme/3378">Москва</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/78">Санкт-Петербург</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/36">Воронеж</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/66">Екатеринбург</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/18">Ижевск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/16">Казань</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/23">Краснодар</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/24">Красноярск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/52">Нижний Новгород</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/54">Новосибирск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/59">Пермь</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/61">Ростов-на-Дону</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/63">Самара</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/64">Саратов</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/2">Уфа</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/74">Челябинск</a>
# </li>
# <li class="regions__item">
# <a class="regions__link" href="/regions/76">Ярославль</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="actual">
# <div class="layout">
# <div class="main">
# <div class="actual__body slider slider-actual">
# <div class="actual__nav_button actual__nav_button--prev slider-prev">
# <a class="actual__nav_button_link slider-link link" href="#">
# <span class="vicon vicon--larrow">
# <svg class="vicon__body">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="vh">Предыдущая страница</span>
# </a>
# </div>
# <ul class="actual__list slider-canvas">
# <li class="actual__item slider-item">
# <ul class="actual__money slider-actual-item">
# <li class="actual__money_item">
# <a class="no_decor slider-link actual__raise" href="/indices?from=actualno">$ 76,08</a>
# </li>
# <li class="actual__money_item">
# <a class="no_decor slider-link actual__raise" href="/indices?from=actualno">€ 82,70</a>
# </li>
# <li class="actual__money_item">
# <a class="no_decor slider-link actual__fall" href="/indices?from=actualno">IMOEX 2592,72</a>
# </li>
# </ul>
# <a class="actual__link slider-link slider-actual-item" href="/doc/5295596?from=actualno">Что посмотреть в кино</a>
# <a class="actual__link slider-link slider-actual-item" href="/weekend?from=actualno">Свежий Weekend</a>
# <a class="actual__link slider-link slider-actual-item" href="/doc/5304051?from=actualno">Валютный прогноз</a>
# <a class="actual__link slider-link slider-actual-item" href="/doc/4300685?from=actualno">Подбор вклада в топ-банках</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/3423?from=actualno">Военная операция на Украине</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/2036?from=actualno">Санкции против России</a>
# <a class="actual__link slider-link slider-actual-item" href="/rubric/149?from=actualno">Эксклюзивы «Ъ»</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/3304?from=actualno">Пандемия</a>
# <a class="actual__link slider-link slider-actual-item" href="/theme/943?from=actualno">Андрей Колесников о Владимире Путине</a>
# </li>
# </ul>
# <div class="actual__nav_button actual__nav_button--next slider-next">
# <a class="actual__nav_button_link slider-link link" href="#">
# <span class="vicon vicon--rarrow">
# <svg class="vicon__body">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="vh">Следующая страница</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <main>
# <div class="layout">
# <div class="search">
# <section class="main grid">
# <div class="grid-col grid-col-s3">
# <div class="service_menu">
# <div class="service_menu__item">
# <input class="hide js-toggle-input" id="search_rules" type="checkbox"/>
# <label class="ui-icon" for="search_rules">
# <span class="icon_text js-toggle-item" data-toggle-id="search_rules">
#                                         Правила поиска
#                                     </span>
# <span class="ui-rotate js-toggle-item" data-toggle-class-checked="ui-rotate_180" data-toggle-id="search_rules">
# <span class="service_menu__arrow vicon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </span>
# </label>
# </div>
# </div>
# <div class="ui-collapse js-toggle-collapse js-toggle-item ui-collapse--hide" data-toggle-class-animated="ui-collapse--animated" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_rules">
# <div class="service_panel doc">
# <p class="simple_page_section_name"><b>В качестве поисковых терминов можно использовать:</b></p>
# <ul>
# <li>отдельное слово;</li>
# <li>несколько слов, разделенных пробелами (поиск документов, включающих все слова).</li>
# </ul>
# <p class="simple_page_section_name"><b>Поиск производится:</b></p>
# <ul>
# <li>без учета строчных и прописных букв;</li>
# <li>игнорируя знаки пунктуации.</li>
# </ul>
# <p class="simple_page_section_name"><b>Дополнительные условия:</b></p>
# <ul>
# <li>в запрос могут быть включены операторы-связки (AND, OR, NOT) и оператор близости (NEAR);</li>
# <li>слова запроса могут иметь символ обобщения (*), но только в конце слова;</li>
# <li>слова при поиске интерпретируются с учетом словоформ.</li>
# <li>для поиска по точной форме запроса этот запрос нужно указать в кавычках.</li>
# </ul>
# <p class="simple_page_section_name"><b>Замечания:</b></p>
# <ul>
# <li>при использовании специальных символов (&amp;, |, ^, #, @, $, (, ), *) запрос следует взять в кавычки;</li>
# <li>для поиска слов, заключенных в кавычки, весь запрос следует также заключить в кавычки.</li>
# </ul>
# <p class="simple_page_section_name"><b>Пример запроса и результаты поиска:</b></p>
# <p class="doc__text">
# <b>Запрос:</b> "банк "Империал""<br/>
# <b>Результат:</b> Статьи, включающие фразу «банк "Империал"»<br/>
# </p>
# <p class="doc__text">
# <b>Запрос:</b> Курс and доллара<br/>
# <b>Результат:</b> Статьи, имеющие оба слова «курс», «доллара»<br/>
# </p>
# <p class="doc__text">
# <b>Запрос:</b> Курс or "доллар*" or "высок"<br/>
# <b>Результат:</b> Статьи, включающие одно из слов — «курс», «доллар», «доллара», «долларов», «долларовая», «высокого», «высокому» и т.д.<br/>
# </p>
# </div>
# </div>
# <header class="simple_page__header">
# <h1 class="simple_page__name">
#                                 Поиск
#                             </h1>
# </header>
# <form action="/search/results" class="doc ui-list js-search">
# <div class="ui-field_pack">
# <input class="ui-input ui-input--search" name="search_query" placeholder="Поиск" type="search" value="python"/>
# <button class="ui-button ui-button--standart ui-button--wide ui-button--smallest_vw_rgap" type="submit">Искать</button>
# <input class="vh js-toggle-input js-state-trigger" id="search_extend" type="checkbox"/>
# <label class="ui-button ui-button--standart ui-button--wide js-state-item" data-state-class-focus-visible="is_focused" data-state-id="search_extend" for="search_extend">
#             Расширенный поиск
#             <span class="vicon vicon--gull_down search__arrow">
# <svg class="vicon__body ui-rotate js-toggle-item" data-toggle-class-checked="ui-rotate_180" data-toggle-id="search_extend">
# <use xlink:href="#vicon-rarrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# </div>
# <section class="simple_page_section simple_page_section--no_margin js-search-settings">
# <h2 class="simple_page_section_name">Как сортировать?</h2>
# <div class="grid">
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input class="ui-radio js-search-radio" name="sort_type" type="radio" value="1"/>
# <span class="ui-text">по релевантности</span>
# </label>
# </p>
# </div>
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input checked="" class="ui-radio js-search-radio" name="sort_type" type="radio" value="0"/>
# <span class="ui-text">по дате</span>
# </label>
# </p>
# </div>
# </div>
# </section>
# <div class="ui-collapse js-toggle-collapse js-toggle-item ui-collapse--hide" data-toggle-class-animated="ui-collapse--animated" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_extend">
# <section class="simple_page_section simple_page_section--no_margin">
# <h2 class="simple_page_section_name">Где искать?</h2>
# <div class="grid js-search-settings">
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input checked="" class="ui-radio js-toggle-input js-search-radio js-search-anywhere" id="search_place_all" name="search_full" type="radio" value="1"/>
# <span class="ui-text">везде</span>
# </label>
# </p>
# </div>
# <div class="grid-col grid-col-half">
# <p class="doc__text">
# <label>
# <input class="ui-radio js-toggle-input js-search-radio" id="search_place_src" name="search_full" type="radio" value="2"/>
# <span class="ui-text">укажите источник</span>
# </label>
# </p>
# </div>
# </div>
# <div class="ui-collapse js-toggle-collapse js-toggle-item" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_place_all"></div>
# <div class="search__ui_indent ui-collapse js-toggle-collapse js-toggle-item" data-toggle-class-animated="ui-collapse--animated" data-toggle-class-checked="ui-collapse--show" data-toggle-class-unchecked="ui-collapse--hide" data-toggle-id="search_place_src">
# <p class="doc__text search__text_indent"><b>в материалах федеральных изданий</b></p>
# <ul class="search_list">
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-checkboxgroup" data-checkboxgroup-selector=".js-search-checkbox-federal" name="ru_all" type="checkbox"/>
# <span class="ui-text">
#                                 все  (10)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="1"/>
# <span class="ui-text">
#                                 в газете «Коммерсантъ»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="6,34,52,61,62,198,242"/>
# <span class="ui-text">
#                                 в тематических приложениях  (6)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="86,284,286"/>
# <span class="ui-text">
#                                 в лентах новостей                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="57,258,259,260,261,262,263,285,295,296,303"/>
# <span class="ui-text">
#                                 в материалах сайта  (3)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="2"/>
# <span class="ui-text">
#                                 в журнале «Власть» и еженедельнике «Ъ»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="84"/>
# <span class="ui-text">
#                                 в журнале «Огонек»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="14"/>
# <span class="ui-text">
#                                 в журнале «Weekend»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="5"/>
# <span class="ui-text">
#                                 в журнале «Автопилот»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="3"/>
# <span class="ui-text">
#                                 в журнале «Деньги»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="217"/>
# <span class="ui-text">
#                                 в журнале «Наука»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="210"/>
# <span class="ui-text">
#                                 в материалах «Коммерсантъ FM»  (1)                            </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="66"/>
# <span class="ui-text">
#                                 в журнале «Citizen K»                             </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox-federal js-search-checkbox" name="places" type="checkbox" value="17"/>
# <span class="ui-text">
#                                 в журнале «Секрет Фирмы»                             </span>
# </label>
# </li>
# </ul>
# <ul class="search_list">
# <li class="search_list__item">
# <label>
# <input class="search_list__tick ui-checkbox js-search-checkbox js-search-checkbox-special" name="categories" type="checkbox" value="18"/>
# <span class="ui-text">
# <b>в фотогалереях</b> </span>
# </label>
# </li>
# <li class="search_list__item">
# <label>
# ...
#         ownerId: 1092,
#         containerId: 'adfox_1486973896119987',
#         params: Object.assign({
#             p1: 'bwfpj',
#             p2: 'fmox',
#             pct: 'c',
#             pp: 'g'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 1197.99,
#             phoneWidth: 1197.99,
#      })
#   })
# </script>
# </div>
# </div>
# </div>
# <div id="lenta">
# <aside class="grid-col-lenta aside_column">
# <section class="aside_news">
# <header class="aside_news__header">
# <h2 class="aside_news__header_name">
# <a class="link aside_news__header_link" href="/lenta">Лента</a>
# </h2>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <article class="aside_news__item">
# <div class="aside_news__text">
# <h4 class="aside_news__date aside_news__placeholder inline_placeholder"></h4>
# <h2 class="aside_news__name aside_news__placeholder inline_placeholder"></h2>
# <h3 class="aside_news__subheader aside_news__placeholder inline_placeholder"></h3>
# <h3 class="aside_news__subheader aside_news__placeholder_middle inline_placeholder"></h3>
# </div>
# </article>
# <a class="title_more aside_news__more" href="/lenta">Вся лента</a>
# </header></section>
# </aside>
# <input class="hide" id="news_lenta_compact" type="checkbox"/>
# <section class="basement_news">
# <header class="basement_news__header">
# <div class="layout">
# <h2 class="basement_news__title">
# <a class="basement_news__link basement_news__header_link" href="#">Лента</a>
# </h2>
# <div class="basement_news__header_body hide_closed">
# </div>
# </div>
# </header>
# <div class="layout basement_news__body">
# <div class="basement_news__list">
# <article class="basement_news__item hide_opened">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# <article class="basement_news__item hide_closed">
# <div aria-hidden="true" class="basement_news__date inline_placeholder"></div>
# <div class="basement_news__text">
# <div class="basement_news__text vh">Загрузка новости...</div>
# <div aria-hidden="true" class="basement_news__name inline_placeholder"></div>
# <div aria-hidden="true" class="basement_news__subheader inline_placeholder"></div>
# </div>
# </article>
# </div>
# </div>
# <footer class="basement_news__footer hide_closed">
# <div class="layout">
# <a class="basement_news__more" href="/lenta">Вся лента</a>
# </div>
# </footer>
# </section>
# </div>
# <footer class="footer">
# <div class="layout">
# <div class="grid main">
# <div class="footer_content">
# <div class="footer_section footer_rusfond">
# <a class="footer_rusfond__link footer__link" href="//rusfond.ru" target="_blank">
# <p class="footer__title footer__title--grey">Благотворительный фонд</p>
# <div class="footer_rusfond__logo">
# <picture class="js-lazyimage">
# <img alt="Русфонд" class="footer_rusfond__img js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/ContentFlex/images/redesign2020/rusfond_label.png" src="..."/>
# </picture>
# <noscript>
# <img alt="Русфонд" class="footer_rusfond__img fallback_image" src="https://im.kommersant.ru/ContentFlex/images/redesign2020/rusfond_label.png"/>
# </noscript>
# </div>
# </a>
# </div>
# <div class="footer_section footer_nav">
# <ul class="footer_nav__list">
# <li class="footer__title"><a class="footer__link" href="/about">О «Коммерсанте»</a></li>
# <li class="footer__title"><a class="footer__link" href="/archive">Архив</a></li>
# <li class="footer__title"><a class="footer__link" href="/contacts">Контакты</a></li>
# <li class="footer__title"><a class="footer__link" href="/ad">Реклама</a></li>
# <li class="footer__title"><a class="footer__link" href="/vacancies">Вакансии</a></li>
# </ul>
# <ul class="footer_nav__list">
# <li class="footer__title"><a class="footer__link" href="/digital">iOS&amp;Android</a></li>
# <li class="footer__title"><a class="footer__link" href="/LK/Feedback">Обратная связь</a></li>
# <li class="footer__title"><a class="footer__link" href="/copyright">Правовая информация</a></li>
# <li class="footer__title"><a class="footer__link" href="/lk/notification">E-mail рассылки</a></li>
# </ul>
# </div>
# <div class="footer_section footer_social">
# <!--                     <a href="https://www.facebook.com/kommersant.ru" class="footer_social__link" title="Фейсбук" target="_blank"> -->
# <!--                         <span class="vicon vicon--circled vicon--fb footer_social__icon"> -->
# <!--                             <svg class="vicon__body"> -->
# <!--                                 <use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="#vicon-fb"></use> -->
# <!--                             </svg> -->
# <!--                         </span> -->
# <!--                     </a> -->
# <a class="footer_social__link" href="https://vk.com/kommersant_ru" target="_blank" title="Вконтакте">
# <span class="vicon vicon--circled vicon--vk footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vk" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <!--                     <a href="https://www.instagram.com/kommersant_online/" class="footer_social__link" title="Инстаграм" target="_blank"> -->
# <!--                         <span class="vicon vicon--circled vicon--ig footer_social__icon"> -->
# <!--                             <svg class="vicon__body"> -->
# <!--                                 <use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="#vicon-ig"></use> -->
# <!--                             </svg> -->
# <!--                         </span> -->
# <!--                     </a> -->
# <a class="footer_social__link" href="https://twitter.com/#!/kommersant" target="_blank" title="Твиттер">
# <span class="vicon vicon--circled vicon--tw footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tw" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://ok.ru/group/53942273310836" target="_blank" title="Одноклассники">
# <span class="vicon vicon--circled vicon--ok footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-ok" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://t.me/kommersant" target="_blank" title="Телеграм">
# <span class="vicon vicon--circled vicon--tg footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tg" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://invite.viber.com/?g2=AQASKm3nkHYfLUfAeChUPQpUmuFiN6WagC%2B%2FFdwldgMHhadaBSbY6LiIYBwfMnfV" target="_blank" title="Вайбер">
# <span class="vicon vicon--circled vicon--vb footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vb" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="https://flipboard.com/@Kommersant" target="_blank" title="Флипборд">
# <span class="vicon vicon--circled vicon--flipboard footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-flipboard" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <a class="footer_social__link" href="http://subscribe.ru/author/24276108/list" target="_blank" title="подписка на «Коммерсантъ»">
# <span class="vicon vicon--circled vicon--subscribe_service footer_social__icon">
# <svg class="vicon__body">
# <use xlink:href="#vicon-subscribe-service" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# <span class="footer__age">16+</span>
# </div>
# <div class="footer_section footer_adv">
# <p class="footer__title footer_adv__title footer__title--grey">Партнерские проекты/материалы, новости компаний, материалы с пометкой «Промо» и «Официальное сообщение» опубликованы на коммерческой основе</p>
# <div class="footer_counter hide_mobile">
# <div class="footer_counter__item">
# <!--LiveInternet logo-->
# <a href="http://www.liveinternet.ru/click" target="_blank">
# <img alt="" height="31" src="//counter.yadro.ru/logo?14.1" style="border: 0;" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" width="88"/>
# </a>
# <!--/LiveInternet-->
# </div>
# <div class="footer_counter__item">
# <!-- Rating@Mail.ru logo -->
# <a href="http://top.mail.ru/jump?from=84394" target="_blank">
# <img alt="Рейтинг@Mail.ru" height="31" src="//top-fwz1.mail.ru/counter?id=84394;t=487;l=1" style="border: 0;" width="88"/>
# </a>
# <!-- //Rating@Mail.ru logo -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script async="" src="https://im.kommersant.ru/ContentFlex/Redesign2020/kom2021.commonAsyncJS.js?2204071948420000"></script>
# </body>
# </html>

# %%
# собираем все теги со ссылками на полные тексты новостей
refs = soup.find_all('a', class_='uho__link')
print(len(refs))
print(refs)
# Out:
# 26
# [<a class="uho__link uho__link--overlay" href="/doc/5293079?query=python" target="_blank">Самое главное о профессии геймдизайнера</a>, <a class="uho__link" href="/doc/5293079?query=python" target="_blank"> ... # и Java, затем — <mark>Python</mark> и С++), уметь ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5295067?query=python" target="_blank">Разработчиков поставили на паузу</a>, <a class="uho__link" href="/doc/5295067?query=python" target="_blank">Компания Intel приостановила работу в России, но не распустила нижегородский центр</a>, <a class="uho__link" href="/doc/5295067?query=python" target="_blank"> ... , аналитиков, разработчиков (JAVA, <mark>Python</mark>), SDET, Test Automation ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5292974?query=python" target="_blank">Кадры идут учиться</a>, <a class="uho__link" href="/doc/5292974?query=python" target="_blank">Какие специалисты востребованы у работодателей</a>, <a class="uho__link" href="/doc/5292974?query=python" target="_blank"> ...  безопасности и тестировщиков. <mark>Python</mark>-разработчики никуда не ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5271237?query=python" target="_blank">Расширение штата по всем направлениям!</a>, <a class="uho__link" href="/doc/5271237?query=python" target="_blank"> ...  (Java, .net, JS, <mark>Python</mark>, Golang, мобильная разработка ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5258915?query=python" target="_blank">EPAM System и JetBrains приостанавливают деятельность</a>, <a class="uho__link" href="/doc/5258915?query=python" target="_blank">IT-компании, арендовавшие в Петербурге десятки тысяч квадратных метров, переводят сотрудников в другие страны</a>, <a class="uho__link" href="/doc/5258915?query=python" target="_blank"> ... #, F#, C++, Ruby, <mark>Python</mark>, PHP, JavaScript и ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5238663?query=python" target="_blank">Porsche Macan в третьем поколении</a>, <a class="uho__link" href="/doc/5238663?query=python" target="_blank">Компания Porsche представила третье поколение моделей Macan, отличающихся от своих предшественников новой концепцией управления, а также более динамичными ходовыми качествами и энергичным дизайном</a>, <a class="uho__link" href="/doc/5238663?query=python" target="_blank"> ...  Metallic, а также <mark>Python</mark> Green для Macan ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5179940?query=python" target="_blank">Требуются продавцы. Срочно!</a>, <a class="uho__link" href="/doc/5179940?query=python" target="_blank">Топ-10 вакансий и резюме в Ярославской области в 2021 году</a>, <a class="uho__link" href="/doc/5179940?query=python" target="_blank"> ...  тыс. руб., «программист <mark>Python</mark>» — 137,5 тыс ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5171805?query=python" target="_blank">Два центра цифрового образования создадут в Удмуртии в 2022 году</a>, <a class="uho__link" href="/doc/5171805?query=python" target="_blank"> ...  учить программированию на <mark>Python</mark>, разработке VR/AR ...  направлениям: «Программирование на <mark>Python</mark>», «Разработка VR/AR ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5139396?query=python" target="_blank">Битва за кадры</a>, <a class="uho__link" href="/doc/5139396?query=python" target="_blank">Как государство помогает готовить специалистов для цифровой экономики</a>, <a class="uho__link" href="/doc/5139396?query=python" target="_blank"> ...  по Data Science, <mark>Python</mark>-разработчик, разработчик «1С ... </a>, <a class="uho__link uho__link--overlay" href="/doc/5140728?query=python" target="_blank">Нижегородские школьники смогут бесплатно пройти курсы по программированию</a>, <a class="uho__link" href="/doc/5140728?query=python" target="_blank"> ...  изучению языков программирования <mark>Python</mark>, Java, С++ и ... </a>]

# %%
# добираемся до ссылок
all_links = []

for ref in refs:
    all_links.append(ref.get('href'))

print(len(all_links))
print(all_links)
# Out:
# 26
# ['/doc/5293079?query=python', '/doc/5293079?query=python', '/doc/5295067?query=python', '/doc/5295067?query=python', '/doc/5295067?query=python', '/doc/5292974?query=python', '/doc/5292974?query=python', '/doc/5292974?query=python', '/doc/5271237?query=python', '/doc/5271237?query=python', '/doc/5258915?query=python', '/doc/5258915?query=python', '/doc/5258915?query=python', '/doc/5238663?query=python', '/doc/5238663?query=python', '/doc/5238663?query=python', '/doc/5179940?query=python', '/doc/5179940?query=python', '/doc/5179940?query=python', '/doc/5171805?query=python', '/doc/5171805?query=python', '/doc/5139396?query=python', '/doc/5139396?query=python', '/doc/5139396?query=python', '/doc/5140728?query=python', '/doc/5140728?query=python']

# %%
# исключаем дубли
all_links = set(all_links)
print(len(all_links))
# Out:
# 10

# %%
# формируем полноценные ссылки
all_full_links = list(map(lambda x: 'https://www.kommersant.ru' + x, all_links))
print(all_full_links)
# Out:
# ['https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python']

# %%
# объединим все в одну функцию
def get_all_links(query):
    url = 'https://www.kommersant.ru/search/results'
    params = {
        'search_query': query,
    }
    res = requests.get(URL, params)
    soup = BeautifulSoup(res.text)
    refs = soup.find_all('a', class_='uho__link')

    all_links = []
    for ref in refs:
        all_links.append(ref.get('href'))
    
    all_links = set(all_links)

    all_full_links = list(map(lambda x: 'https://www.kommersant.ru' + x, all_links))

    return all_full_links

all_links = get_all_links('python')
print(all_links)
# Out:
# ['https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python']

# %%
# но мы же собрали только одну страницу? Хотим ВСЕ новости
def get_all_links(query, pages):
    url = 'https://www.kommersant.ru/search/results'
    links_list = []
    params = {
        'search_query': query
    }
    for i in range(1, pages+1):
        params['page'] = i
        res = requests.get(URL, params)
        time.sleep(0.3)

        refs = soup.find_all('a', class_='uho__link')
        all_links = []

        for ref in refs:
            all_links.append(ref.get('href'))
        
        all_links = set(all_links)

        all_full_links = list(map(lambda x: 'https://www.kommersant.ru' + x, all_links))

        links_list += all_full_links
    return links_list

all_links = get_all_links('python', 5)
print(len(all_links))
print(all_links)
# Out:
# 50
# ['https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python', 'https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python', 'https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python', 'https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python', 'https://www.kommersant.ru/doc/5179940?query=python', 'https://www.kommersant.ru/doc/5140728?query=python', 'https://www.kommersant.ru/doc/5292974?query=python', 'https://www.kommersant.ru/doc/5295067?query=python', 'https://www.kommersant.ru/doc/5293079?query=python', 'https://www.kommersant.ru/doc/5139396?query=python', 'https://www.kommersant.ru/doc/5271237?query=python', 'https://www.kommersant.ru/doc/5171805?query=python', 'https://www.kommersant.ru/doc/5258915?query=python', 'https://www.kommersant.ru/doc/5238663?query=python']

# %%
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text)
    time.sleep(0.3)
    date = pd.to_datetime(soup.find('time', class_='doc_header__publish_time').get('datetime'))
    print(date)
    title = soup.find('h1', class_='doc_header__name').text
    print(title)
    text = soup.find('div', class_='doc__body').text
    print(text)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Самой востребованной вакансией в Ярославской области в 2021 году стала вакансия «продавец», включающая вариации «продавец-консультант», «кассир» и другие синонимы профессии. Соответствующее исследование провела платформа онлайн-рекрутинга hh.ru. Количество вакансий «продавец» в регионе по итогам прошедшего года приблизилось к 5 тыс., заняв долю 6,8% от общего числа доступных вакансий в регионе.
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Фото: Иван Водопьянов, Коммерсантъ
#
#
#
#
#
#
#
#
# Фото: Иван Водопьянов, Коммерсантъ
#
#
#
#
# Водители — вторая по востребованности профессия. Количество вакансий на платформе — 3,1 тыс., доля от общего количества по региону — 4,6%. Третье место по востребованности заняли вакансии «менеджер по продажам» — 2,6 тыс. штук, эквивалентных 3,8% от общего количества по Ярославской области.
# Самой востребованной профессии «продавец» ярославские работодатели предлагают среднюю заработную плату в размере 28 тыс. руб. Средняя предлагаемая зарплата водителей, водителей-экспедиторов и таксистов в Ярославской области — 50 тыс. руб., менеджеров по продажам — 45 тыс. руб.
# Наиболее высокооплачиваемыми вакансиями в Ярославском регионе стали «Финансовый директор» со средней зарплатой в размере 200 тыс. руб., «программист JS» — 167,5 тыс. руб., «Java-разработчик» — 155 тыс. руб., «программист Python» — 137,5 тыс. руб., и «водитель категории Е» со средней заработной платой в размере 135 тыс. руб.
# По данным специалистов платформы онлайн-рекрутинга, количеством резюме в 2021 году отличилась профессия «начинающий специалист». На сайте представлено 7,6 тыс. резюме от соискателей этой профессии, доля от общего количества резюме составила 6,6%. На втором месте — «продавец» и его вариации — 4,6 тыс. резюме с долей 4,1% от общего количества предложений, что почти соответствует объему вакансий. Третьей профессией, наиболее часто предлагаемой соискателями, стала «администратор» — 3,8 тыс. резюме на сайте hh.ru. Профессия заняла 3,3% от общего количества резюме сервиса рекрутинга в Ярославской области за минувший год.
# Глеб Гузенко
#
# Все важнейшие новости Ярославии читайте в нашем Telegram-канале
#
# 2021-12-20 17:37:05+03:00
#
#         Нижегородские школьники смогут бесплатно пройти курсы по программированию
#
#
#
#
#
#
#
#
#
#
#
#
#         395
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 1 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Программу бесплатного обучения школьников программированию распространили на Нижегородскую область и еще четыре региона — Калужскую, Тульскую, Оренбургскую области и Башкортостан. Об этом сообщили в Министерстве цифрового развития РФ.
# Пройти курсы бесплатно смогут учащиеся школ старше 14 лет. Проект реализуют Минцифры России и платформа онлайн-обучения «Университет 2035». Всего в программу включили 10 пилотных регионов.
# Школьникам предлагают пройти курсы по изучению языков программирования Python, Java, С++ и другие программы. Чтобы записаться на курс, необходимо до 30 декабря выбрать программу обучения в каталоге, заполнить анкету вместе с родителем или законным представителем, пройти тестирование по основам программирования и заключить договор на бесплатное обучение.
# Курсы будут проходить в мае-июне 2022 года, минимальная продолжительность – 144 академических часа. Бесплатно каждый школьник может пройти только один курс.
# Обучение проводят девять организаций: «Алгоритмика», Университет «Иннополис», 1С-Образование, «Фоксфорд», «Кодемика», «Инжинириум» МГТУ имени Баумана, «Мобильное электронное образование», Университет «Синергия» и Центр современных образовательных технологий и систем.
# Анастасия Еремина
#
# 2022-04-03 15:28:40+03:00
#
#         Кадры идут учиться
#
#
#
#
#
#
#
#
#
#
#
#
#         915
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 3 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Российский бизнес намерен обучить сотрудников китайскому языку. По крайней мере, спрос на таких специалистов в марте вырос, говорят данные образовательной платформы Skillbox. Есть интерес к преподавателям арабского, хинди и языков азиатской группы. Востребованными у компаний остаются фотографы, видеомонтажеры, SMM-менеджеры и digital-маркетологи. Все потому, что бизнес продолжает создавать контент и пытается найти дополнительные способы привлечения аудитории, поясняют в Skillbox. Не падает спрос и на специалистов по кибербезопасности.
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Фото: Эмин Джафаров, Коммерсантъ
#
#
#
#
#
#
#
#
# Фото: Эмин Джафаров, Коммерсантъ
#
#
#
#
# Предприятия, которые пытаются перестроиться на новые, доступные рынки, запрашивают для своей команды курсы по антикризисному управлению, говорит руководитель направления дополнительного профессионального образования «Нетологии» Елена Герасимова: «Особенно востребованными у юрлиц становятся программы переквалификации команд.
#
#
# Какую программу занятости разработали в SuperJob
#
#
# Если компания приняла поворот на новые рынки или продукты, то она вынуждена быстро осваивать компетенции, краткосрочные курсы, готовить команду в интенсивном режиме. Интересуются антикризисными тематиками, управлением персоналом, курсами, связанными с созданием продуктов, новой реальности. Стало катастрофически сложно искать разработчиков, произошел большой отток специалистов уровня middle и выше. При этом на рынке все еще дефицит IT-работников.
# Чаще стали спрашивать специалистов в области информационной безопасности и тестировщиков. Python-разработчики никуда не делись и, кажется, будут долго в связи с популярностью микросервисов. Я хочу подчеркнуть спрос на системных аналитиков. Год назад мы активно рекламировали все специальности, которые являются флагманскими: аналитика, дизайн, маркетинг в области информационных технологий. Интерес растет, при этом людей, которые не хотят идти в IT, большая часть».
#
#
# На сколько может сократиться число рабочих мест в российской экономике
#
#
#
#                     Читать далее
#
#
#
#
#
#
# Еще один запрос российского бизнеса — развитие навыков пользования иностранными языками для переговоров. Компаниям сейчас важно не только подтянуть деловой английский у сотрудников, но и обучить китайскому языку, делится гендиректор сети школы иностранных языков Star Talk Екатерина Белятинская: «Корпоративный сектор прошел через фазу шока, мы замечали примерно по 10 обращений в день от корпоративных клиентов. В начале марта наблюдался небольшой спад запросов на обучение, тем не менее мы видим, что постепенно спрос восстанавливается.
#
#
# Топ-менеджеры — о настроениях в коллективе
#
#
# Компании интересуются чаще всего английским для бизнес-коммуникаций, а также всем, что связано с английским для IT. Сейчас тренд на разговорные клубы с носителем языка, чтобы поддержать моральный дух команд. Бизнес начал в том числе запрашивать для своих сотрудников изучение китайского языка. Повышение интереса наблюдается со стороны B2B- и B2C-организаций. Это как российские, так и международные компании — фарма, IT, ритейл».
# А вот рекламный бизнес нуждается в специалистах, которые занимаются автоматической закупкой таргетированной рекламы, говорит гендиректор агентства PRT Edelman Глеб Сахрай. Отчасти потому, что клиенты начали активно перестраивать SMM-стратегии. На поведении компаний, как отмечает эксперт, сказывается и желание расширить продвижение на азиатский и ближневосточный рынки:
# «Что касается клиентов, которые остались, то это российские, часть международных. Для них, безусловно, контент очень востребован, потому что они отказались от какого-то агрессивного продвижения.Безусловно, они хотят оставаться в информационном поле. Сохранили какие-то SMM-активности, то, что связано с созданием контента. Все заметили, что Telegram стал супермощным каналом, чуть меньше "ВКонтакте".
# Cоцсеть в принципе дает возможность более или менее делать все то же, что и Facebook (принадлежит запрещенной в России Meta). Telegram здесь, наверное, интереснее, поскольку требует других подходов: практичных, лаконичных, с минимумом какой-то мишуры и с максимумом конкретики, иначе люди будут отписываться от каналов. Что касается зарубежных рынков, AliExpress дает какие-то инструменты и возможности самостоятельно продвигать там себя так же, как и в России. Это очень сложно.
#
#
# Какие страны ждут у себя российских разработчиков
#
#
# Китай со своими платформами, Индонезия огромная, Таиланд — с каждым нужно разбираться отдельно. Российский бизнес пока только прощупывает новые рынки. Более простые с точки зрения менталитета — Израиль и Турция. Сейчас хорошо себя чувствует programmatic, особенно локальные компании, которые занимаются этим, поскольку мощными конкурентами здесь были Facebook и Google. Бюджеты перетекли в сторону российских programmatic-игроков».
# В Центре стратегических разработок на этой неделе подсчитали, что к концу года число рабочих мест в российской экономике может сократиться на 2 млн. Тогда уровень безработицы всего за несколько месяцев вырастет почти в два раза. Согласно другому прогнозу, число безработных в стране будет находиться на отметке около 6% в течение ближайших двух-трех лет.
# При этом в организации отметили, что при любом сценарии в России произойдет изменение структуры занятости. В ближайшее время штат серьезно сократят автопроизводители, металлурги и строительные компании. Именно эти отрасли сильнее всего пострадали от санкций. А в сферах IT и легкой промышленности количество вакансий, наоборот, увеличится из-за необходимости импортозамещения.
# Ольга Сергиенко
#
# 2022-04-06 21:09:05+03:00
#
#         Разработчиков поставили на паузу
#
#
#
#
#
#
#
#
#
#
#
#
#         2K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 4 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Американский производитель процессоров Intel приостановил бизнес в России из-за спецоперации на Украине. Крупнейший центр разработок компании находится в Нижнем Новгороде, его сотрудники пока отправлены в корпоративные отпуска с сохранением зарплаты. Компания также не прекратила сотрудничество с вузами, совместные проекты продолжают действовать. Нижегородские власти надеются, что ситуация временная, однако готовы обеспечить специалистов работой для поддержки отечественных разработок программного обеспечения. Эксперты полагают, что высококвалифицированные сотрудники Intel без работы не останутся.
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Intel отправил сотрудников в оплачиваемые отпуска в надежде сохранить рабочие местаФото: Роман Яровицын, Коммерсантъ
#
#
#
#
#
#
#
#
# Intel отправил сотрудников в оплачиваемые отпуска в надежде сохранить рабочие местаФото: Роман Яровицын, Коммерсантъ
#
#
#
#
# Корпорация Intel объявила, что приостанавливает предпринимательскую деятельность в России в связи с ситуацией на Украине. «Мы немедленно приостановили все деловые операции в России. Это следует за нашим предыдущим решением приостановить (в начале марта. — «Ъ») все поставки клиентам в России и Белоруссии», — сообщили в компании. Российским сотрудникам Intel сохранят заработную плату на время простоя, однако время вынужденных «каникул» специалистов не называется. По словам источников, пока говорится о двух месяцах простоя.
# Сегодня у российского бизнеса Intel есть два центра — в Москве и Нижнем Новгороде, ранее корпорация имела представительства в Новосибирске и Санкт-Петербурге, но закрыла их.
# Открытый в 2000 году нижегородский центр исследований и разработок (RnD) является одним из крупнейших в Европе и объединяет лаборатории и подразделения по разработке кросс-платформенного программного обеспечения, решений для искусственного интеллекта, компьютерного зрения. В Нижегородской области компания Intel стояла у истоков создания технопарков «Анкудиновка» и «Саров». В 2020 году губернатор Глеб Никитин анонсировал сотрудничество с корпорацией по проекту научно-образовательного центра мирового уровня «Техноплатформа-2035».
# Одним из направлений нижегородского НОЦ являются цифровые технологии, искусственный интеллект и интеллектуальные транспортные системы. Также Intel развивал образовательные программы совместно с нижегородскими вузами. Например, с госуниверситетом имени Лобачевского компания создала в 2020 году первый в России центр компетенций oneAPI, специализирующийся на исследованиях в области физики на базе архитектур и аппаратных ускорителей с использованием кроссплатформенной модели программирования. Также в вузе работает образовательная программа по высокопроизводительным вычислениям, искусственному интеллекту и компьютерному зрению.
# Это направление Intel реализует и с нижегородским кампусом Высшей школы экономики, которая, как и ННГУ, занимается подготовкой кадров для компании. Судя по всему, взаимодействие продолжится: Intel не отказалась от сотрудничества по образовательным программам. В ННГУ сообщили, что не получали от корпорации подобных уведомлений, в вузе следят за развитием ситуации с партнером.
# На факультет информатики, математики и компьютерных наук ВШЭ-Нижний Новгород также не приходило никаких писем от Intel, отметила его декан Наталья Асеева. По ее словам, сотрудники компании, работающие по совместительству преподавателями, пока не заявляли о расторжении договора с факультетом.
# «Научные и образовательные направления, в рамках которых мы сотрудничаем с Intel, не будут закрыты, даже в случае, если они уйдут. Факультет продолжит развивать их самостоятельно или в партнерстве с другими компаниями», — добавила госпожа Асеева. Компания Intel также планировала участвовать в проекте по созданию IT-кампуса «Неймарк» в Нижнем Новгороде. В проектном офисе стратегии развития Нижегородской области уточнили, что компания должна была участвовать в образовательных программах, речи о финансировании этого проекта не было. Комментируя решение Intel приостановить бизнес в России, губернатор Глеб Никитин напомнил, что нижегородский офис выпустил не одно поколение IT-предпринимателей и ведущих разработчиков, которые развивают российскую отрасль.
# «Будем надеяться, что приостановка временная. А если все же компания прекратит работу в России, то мы готовы обеспечить работой нижегородских специалистов. Уже неоднократно говорил, что для нас главный приоритет — люди», — сообщил губернатор. По его словам, нижегородские власти готовы помочь разработчикам с трудоустройством и обеспечить достойные условия жизни, поскольку важно поддержать разработку отечественного софта.
# Директор нижегородского IT-кластера Марат Мухарьямов считает возможный уход Intel большой потерей для отрасли. «Офис Intel был одним из старожилов. Благодаря ему в Нижнем Новгороде есть высокие компетенции, в том числе в области высокопроизводительных вычислений», — сообщил он.
# По словам эксперта, кадровый рынок в IT сегодня переживает не лучшие времена, когда многие компании вынуждены релоцироваться, закрывая офисы в России. В результате на рынке появляются высококвалифицированные специалисты, которых ранее невозможно было найти. «Думаю, большинство из них будут востребованы рынком. Вряд ли они надолго останутся без работы. Как правило, в таких ситуациях специалисты начинают обновлять резюме и рассматривать предложения. Учитывая, что в Intel работали высококвалифицированные сотрудники, без работы они не останутся», — подытожил Марат Мухарьямов.
# Власти также озабочены оттоком IT-специалистов из региона. Ранее губернатор говорил, что Нижегородскую область после начала спецоперации на Украине покинули 400 работников, а в перспективе могут уехать еще 4 тыс. человек. По данным центра искусственного интеллекта «Горький», в первую очередь страну покидают высокомобильные профессионалы и специалисты узкого профиля: CV, BigData, Pentester. Далее идет отток менеджеров проектов, аналитиков, разработчиков (JAVA, Python), SDET, Test Automation-инженеров, QA и DevOps-инженеров, которые были задействованы в международных/иностранных проектах.
# «В настоящий момент сложно учитывать, кто уехал насовсем. Есть случаи возвращения в силу возникающих при релокации сложностей и благодаря принимаемым мерам поддержки IT-отрасли на федеральном и региональном уровнях», — добавили в центре «Горький».
# Роман Рыскаль
#
# 2022-04-07 15:48:19+03:00
#
#         Самое главное о профессии геймдизайнера
#
#
#
#
#
#
#
#
#
#
#
#
#         4K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 5 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Основные направления работы геймдизайнера, где учатся на эту профессию, ее плюсы и минусы — в материале «Ъ».
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Фото: Александр Миридонов, Коммерсантъ
#
#
#
#
#
#
#
#
# Фото: Александр Миридонов, Коммерсантъ
#
#
#
#
# Кто такой геймдизайнер
# Геймдизайнером в самом общем смысле называют человека, который является ответственным за создание игры. Геймдизайнер придумывает идею и занимается конструированием игрового мира. Он создает правила, по которым будет работать игра, проектирует игровые механики, а также определяет, какие эмоции должен будет испытывать геймер в определенные моменты игры. Если сравнивать с кинематографом, то ближайший аналог геймдизайнера — режиссер.
# Геймдизайнер связан со всеми процессами жизненного цикла игры. Он занимается контролем работы программистов, сценаристов, художников — всех, кто имеет отношение к созданию игры.
# Геймдизайнер также ответственен за написание дизайн-документа — в нем подробно описывается игра, ее механики, сюжет, сеттинг. Геймдизайнер должен уметь планировать весь процесс создания игры.
# В профессии велико творческое начало, однако также часто оказывается, что геймдизайнер должен выполнять всю работу, для которой нет выделенного специалиста.
# Основные направления работы геймдизайнера
# В небольших студиях геймдизайнер может выполнять сразу несколько ролей, однако в крупных компаниях за различные специализации отвечают разные геймдизайнеры, так как разработка высокобюджетных игр требует участия сотен или даже тысяч разработчиков.
# Системный дизайнер, создающий общие правила игры. Это тот человек, кто будет придумывать игровые механики.
# Дизайнер баланса, который устанавливает сложность игры, а также следит за тем, чтобы все игроки находились в равных условиях, если игра, к примеру, многопользовательская.
# Нарративный дизайнер, который отвечает за подачу сюжета, разработку мифологии, создание сеттинга — мира игры, где будут происходить события.
# Дизайнер миссий отвечает за создание квестов и разработку структуры миссий. Иногда он еще одновременно и дизайнер уровней (левел-дизайнер) — тот, кто проектирует уровни в игре.
# UI/UX-дизайнер разрабатывает интерфейс, то есть то, как геймер будет взаимодействовать с игрой, и то, как она будет отвечать на действия пользователя.
# Дизайнер экономики и монетизации. Часто в играх есть собственная экономика и валюта, а также возможность тратить реальные деньги на внутриигровые товары — разработкой этой области может заниматься отдельный специалист.
# Самые известные геймдизайнеры
# Имя японского разработчика игр Хидэо Кодзимы уже давно стало нарицательным, когда разговор заходит о геймдизайнерах. Он является создателем серии Metal Gear, а его последней игрой на данный момент стала Death Stranding.
# Сигэру Миямото — один из ключевых геймдизайнеров Nintendo, придумавший игры про Марио и The Legend of Zelda.
# Алексей Пажитнов — советский программист, придумавший «Тетрис».
# Кен Левин является автором Bioshock и System Shock 2.
# Джон Ромеро придумал DOOM и Quake.
# Джордан Мехнер в одиночку разработал двухмерного Prince of Persia.
# Сэм Хаузер является одним из создателей серии Grand Theft Auto (GTA).
# Мишель Ансель — создатель серий Rayman и Beyond Good & Evil.
# Нил Дракман отвечает за разработку серий The Last of Us и Uncharted.
# Сид Мейер — автор культовых Sid Meier’s Civilization и Sid Meier’s Pirates.
# Питер Молинье является создателем Black & White и Fable.
# Клиф Блезински придумал серию Gears of War.
# Что нужно для начала работы геймдизайнером
# К геймдизайнерам всегда повышенные требования: им необходимо владеть различными навыками в разных сферах. В небольших компаниях геймдизайнер может быть еще и менеджером продукта или даже продюсером — заниматься составлением дедлайнов, ставить задачи сотрудникам.
# Вследствие этого для начала нужно занять прокачиванием навыков, ведь для разработки игр часто необходимо знать основы программирования (самыми распространенными языками в играх являются C# и Java, затем — Python и С++), уметь работать в Photoshop, разбираться в игровых движках, придумывать сюжет и писать сценарий для игры.
# Можно пройти онлайн-курсы или почитать литературу на тему, например Джесси Шелл «The Art of Game Design: A Book of Lenses» или Скотт Роджерс «Level Up! The Guide to Great Video Game Design».
# Важно знать основные тренды на рынке видеоигр, уметь увидеть, что модно сейчас, и попытаться предугадать, что будет модно к концу разработки игры. Важно понимать, для какой целевой аудитории делается проект.
# Также можно пройти обучение геймдизайну в Высшей школе экономики, где есть программа «Геймдизайн и виртуальная реальность». Также в Санкт-Петербургском государственном университете промышленных технологий и дизайна есть программа бакалавриата «Анимация и графика компьютерных игр».
# Многие геймдизайнеры начинают с собственных инди-проектов — для их создания потребуется всего несколько человек. Другой способ попасть в профессию — через должность тестировщика.
# Плюсы и минусы профессии
# Плюсы:
# · высокие доходы
# · возможность превратить хобби в высокооплачиваемую работу
# · творческая профессия с разноплановыми задачами
# · востребованность
# Минусы:
# · сложный порог вхождения в профессию
# · необходимость владеть различными навыками в разных сферах
# · трудно убедить общественность, что геймдизайнер — серьезная профессия
# · предложение превышает спрос
# Михаил Вовк, руководитель отдела гейм-дизайна компании-разработчика мобильных игр Pixonic (входит в состав игрового бренда MY.GAMES):
# «Достаточно трудно назвать точную вилку — сколько получают геймдизайнеры в 2022 году. Зарплаты зависят от уровня подготовки геймдизайнера, его умений и опыта работы и могут варьироваться от десятков тысяч до сотен тысяч рублей. Ну и из геймдизайнеров нередко вырастают продюсеры, геймдиректора, директора студий, так что зарплате всегда есть куда расти.
# Для работы геймдизайнером получать высшее образование, скажем так, необязательно, но для конкретных руководителей и на конкретных позициях высшее образование может быть важным фактором. Например, при поисках геймдизайнера-экономиста или балансера хочется быть уверенным в его умении считать. Да и в целом, высшее образование как минимум показывает умение человека учиться и искать информацию. Другое дело, что те же самые навыки можно показать работодателю иначе: через предыдущий опыт работы, личные проекты (включая моды для известных игр), выполнение тестового задания. В общем, отсутствие высшего образования не помеха для геймдизайнера, но это может отрезать некоторые варианты или сделать их несколько более труднодоступными».
# Евгений Федуненко; группа «Прямая речь»
#
# 2021-12-28 00:01:00+03:00
#
#         Битва за кадры
#
#
#
#
#
#
#
#
#
#
#
#
#         522
#
#
#
#
#
#
#
#
#
#                 8 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Цифровая трансформация является одной из национальных целей развития России до 2030 года. Применение цифровых технологий призвано обеспечить качественные изменения в экономике и социальной сфере, в том числе в госуправлении. При этом успешность преобразований во многом зависит от человеческого капитала, «цифровых» кадров — дефицит IT-специалистов в 2024 году прогнозируется на уровне не менее 1 млн человек.
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Фото: Анатолий Жданов, Коммерсантъ
#
#
#
#
#
#
#
#
# Фото: Анатолий Жданов, Коммерсантъ
#
#
#
#
# Федеральный проект «Кадры для цифровой экономики» решает задачи по подготовке специалистов, а также по повышению цифровой грамотности населения, необходимой для использования цифровых технологий. Кроме того, нацпрограмму «Цифровая экономика» с 2022 года дополнит федпроект «Развитие кадрового потенциала IT-отрасли» — на его реализацию правительство планирует направить более 27,9 млрд руб. до 2024 года, сообщил вице-премьер Дмитрий Чернышенко.
# Опора на вузы
# В прошлом году при университете «Иннополис» в Республике Татарстан был создан опорный центр по подготовке специалистов в области цифровой экономики и информационных технологий. В этом году на базе центра сформирован консорциум из высших и средних учебных заведений. По словам вице-премьера Дмитрия Чернышенко, это позволит унифицировать и стандартизировать основные подходы к обучению, а также сформировать образовательные модули по цифровым компетенциям для преподавателей и студентов. По состоянию на 1 декабря прошли обучение цифровым навыкам более 16 тыс. преподавателей, было актуализировано 30 образовательных программ с учетом потребностей современного рынка и 40 профстандартов в части требований к формированию компетенций цифровой экономики.
# «Главная задача Минцифры — обеспечить качество подготовки кадров на таком уровне, чтобы страна могла делать большие цифровые прорывы. Без системы высшего образования решить эту задачу невозможно»,— заявил глава ведомства Максут Шадаев в обращении к участникам форума Digital InnopolisDays 2021. Он отметил, что можно изменить цифры приема, но без изменения качества подготовки специалистов будет невозможно двигаться дальше. В нынешнем году контрольные цифры приема абитуриентов в вузы по IT-специальностям на бюджетные места составили 80 тыс. (в 2020 году — 60 тыс.), к 2024 году этот показатель планируется увеличить до 120 тыс.
# Повышение качества образования требует участия IT-компаний. «И в этом смысле мы призываем региональные большие комьюнити делать — есть опорные вузы в любом регионе»,— заявил министр на встрече с представителями IT-сообщества в Ульяновске.
# Говоря о взаимодействии вузов и бизнеса, руководитель отдела образовательных программ фирмы «1С», координатор рабочей группы «Кадры для цифровой экономики» АНО «Цифровая экономика» Игорь Кузора отмечал, что учебные заведения хотят пригласить бизнес в образовательный процесс, но при этом сохранить его фундаментальность. Для того чтобы замкнуть два этих встречных движения и найти точки соприкосновения, АНО «Цифровая экономика» и Ассоциация предприятий компьютерных и информационных технологий создали проект «ЦифрОбраз». Это информационный ресурс, где представлены предложения бизнеса по улучшению образовательных программ, информация о стажировках, грантах — все то, что по своему желанию вуз может использовать.
# Программирование со школьной скамьи
# Вместе с тем будет невозможно достигнуть контрольных показателей по приему абитуриентов в вузы, если не начать работу еще со старших классов школы. «Это самый главный вызов, если мы его не решим, все остальное в принципе бессмысленно»,— указывал Максут Шадаев.
# В 2022 году предполагается открыть первый набор на программы бесплатного обучения школьников 8–11-х классов языкам программирования на двухгодичных курсах. Вице-премьер Дмитрий Чернышенко отмечал, что новая инициатива призвана помочь школьникам определиться с будущей профессией и сформировать навыки, востребованные в цифровой экономике. Он указывал, что на обучение школьников уже заложено в федеральном бюджете почти 9 млрд руб., которые позволят до 2024 года подготовить 240 тыс. школьников. В 2022 году первые 100 тыс. школьников получат такую возможность. Предполагается, что до 2030 года обучение пройдут 1,2 млн детей. Обучение учащихся предполагается реализовать также в рамках инициативы «Подготовка кадров для IT», которая вошла в число 42 стратегических инициатив, утвержденных правительством в октябре нынешнего года.
# «Пилот» проекта Минцифры запустило в октябре текущего года. Участвовать в нем в 2021 году могли ученики из Белгородской, Новгородской, Пензенской областей, Республики Татарстан и Республики Саха (Якутия). Курсы дополняют школьную программу по математике и информатике, их минимальная продолжительность —144 академических часа. «Пилот» продлится до июня 2022 года, его результаты будут учтены во всероссийском проекте. В декабре к пилотному проекту подключились еще пять регионов: школьники из Калужской, Тульской, Оренбургской, Нижегородской областей и Республики Башкортостан смогут обучиться языкам программирования на бесплатных курсах в рамках пилотного проекта Минцифры России и Университета 2035. Запись на обучение доступна до 30 декабря 2021 года.
# Новая квалификация
# Получение специального высшего образования — это не единственный способ освоить компетенции в сфере IT. Еще одна инициатива Минцифры — создание «цифровых кафедр» в российских вузах, что позволит студентам параллельно с основным направлением обучения, не связанным с IT, получить дополнительные «цифровые» компетенции. Предполагается, что до конца 2024 года будет открыто около 100 кафедр (в основном в региональных вузах), обучение пройдут не менее 260 тыс. студентов. Старт проекта запланирован на 2022 год.
# Кроме того, пройти допобучение можно в рамках программы «Цифровые профессии». Слушателями курсов могут стать россияне от 16 лет с образованием не ниже среднего профессионального и не достигшие пенсионного возраста. При этом студент или его работодатель оплачивает только половину стоимости обучения, другую половину — государство. В среднем цена за курс с учетом 50-процентной скидки составляет около 40 тыс. руб. Обучение длится не менее 250 академических часов, из которых 144 часа посвящены программированию. Предполагается, что до конца 2024 года программой воспользуются минимум 110 тыс. человек. К участию в проекте допущено 46 образовательных организаций. В числе наиболее востребованных у студентов программ — Java-разработчик, специалист по Data Science, Python-разработчик, разработчик «1С», веб-разработчик.
# Госслужащие и сотрудники коммерческих компаний могут пройти обучение по программе повышения квалификации CDO (директор по цифровым технологиям). На выбор им предлагается два курса: «Методы и технологии, основанные на работе с данными» и «Управление, основанное на данных». При этом слушатели не только осваивают цифровые компетенции и проектную деятельность, но и разрабатывают собственные проекты. Отметим, что «цифровое» госуправление должно привести к повышению качества и эффективности оказания госуслуг, проактивной поддержке со стороны государства.
# Цифровой трансформации в России мешают недоверие населения к технологиям и сопутствующая ему низкая цифровая грамотность в защите персональных данных, хотя до двух третей российских работников уже заняты в профессиях со средним уровнем цифровизации, указывали эксперты Высшей школы экономики (ВШЭ). Протестировать уровень цифровой грамотности, а также сформировать необходимые в повседневной жизни IT-навыки можно на специальном портале готовкцифре.рф, где собраны различные инструменты оценки.
# Конкуренция обостряется
# По данным сервиса «Работа.ру», в третьем квартале 2021 года практически во всех отраслях наем новых сотрудников стал еще более активным: число открытых вакансий увеличилось на 48% по сравнению с тем же периодом 2020 года. Вместе со спросом растет и конкуренция за сотрудников: работодатели готовы предлагать более выгодные условия труда для привлечения новых высококвалифицированных кадров, говорит директор по персоналу и организационному развитию сервиса Юлия Санина. «Несмотря на то что эталонные условия труда и высокие зарплаты в IT привлекают все больше россиян в эту сферу (число резюме выросло на 72%), конкуренция работодателей за высококвалифицированных профессионалов в этой отрасли продолжает обостряться — только 52% кандидатов имеют фундаментальное образование в IT»,— указывает она.
# Дефицит IT-кадров в 2024 году составит не менее 1 млн человек, к 2030 году при сохраняющемся тренде показатель достигнет отметки более 3 млн человек — соответствующий прогноз сделала на сессии «Кадровые тренды в сфере IT & Digital эпохи удаленки» в рамках XIII Russian Internet Week (RIW 20/21) замдиректора по направлению «Кадры для цифровой экономики» АНО «Цифровая экономика» Юлия Горячкина. Согласно приведенным в ее презентации данным, 62% компаний считают, что нехватка специализированных кадров препятствует цифровизации.
# Традиционно IT-отрасль является одним из лидеров по уровню зарплат. По данным «Работа.ру», только за лето текущего года зарплаты специалистов выросли в среднем на 20%. В топ-3 профессий с самыми высокими средними зарплатами в отрасли входят технический директор (238 тыс. руб. в месяц), Go-разработчик (195 тыс. руб. в месяц) и продакт-менеджер (171 тыс. руб. в месяц).
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Компании ищут в основном людей с опытом работы в IT более трех лет. Специалистам, которые только пришли в эту сферу, очень сложно, так как кандидатов на junior-позиции много, конкуренция большая, а заработная плата для такого уровня гораздо ниже, чем для уровней middle и выше, отмечает руководитель центра развития карьеры образовательной платформы «Нетология» Татьяна Смирнова. Но несмотря на сегодняшний «тяжелый» вход в IT, большие перспективы есть у специалистов, выбирающих сферы на стыке бизнеса и технологий, промышленности и аналитики данных — эти профессиональные области очень ценятся работодателем, указывает она.
# По словам госпожи Саниной, по количеству вакансий самыми популярными профессиями в IT являются программист Java, frontend-разработчики, системный администратор. Похожие данные приводит руководитель Академии «Яндекса» Евгения Куликова. По ее словам, в последние два года наблюдается спрос на разработчиков мобильных приложений, также сохраняется стабильно высокий спрос на backend- и frontend-разработчиков. Она добавляет, что в настоящее время навыки в области цифровых технологий и анализа данных востребованы не только в «технических» индустриях — они необходимы и в гуманитарных дисциплинах.
# По результатам анализа, проведенного Институтом статистических исследований и экономики знаний НИУ ВШЭ, самыми востребованными навыками в цифровой среде являются работа с базами данных, владение английским языком и машинное обучение, владение методами защиты информации и взаимодействие с клиентами. Таким образом, от соискателей требуются не только профессиональные навыки (hard skills), но и неспециализированные компетенции (soft skills). Soft skills носят кросс-функциональный характер, не привязаны к определенной профессии и могут быть полезными в любой сфере, говорит госпожа Санина. По ее словам, важно обладать критическим мышлением, постоянно повышать свой уровень, учиться новому и уметь взаимодействовать с другими людьми.
# По мнению гендиректора Инжинирингового центра МФТИ Тимура Тавберидзе, чтобы попасть в пул высоковостребованных кандидатов, недостаточно обозначить приставку «digital» к своему IT-опыту — нужно соответствовать этому статусу. Это означает не только получение серьезного фундаментального образования в профильном университете, но и прохождение большого числа курсов, знание иностранного языка для чтения специализированной литературы и постоянное оттачивание навыков на практике, поясняет он.
# Вузовские образовательные программы, ориентированные на практику, отчасти могут решить проблему нехватки квалифицированных IT-кадров, указывает госпожа Куликова. Сложность в том, что для их создания нужно привлекать специалистов, которые прямо сейчас работают в индустрии и знают ее изнутри, отмечает она. Впрочем, компании приходят не только в вузы, но и к образовательным платформам, чтобы, объединившись, создавать программы обучения, ориентированные на запросы организации. Тимур Тавберидзе надеется, что совместные усилия позволят в будущем уравновесить спрос и предложение на digital-специалистов.
# Венера Петрова
#
# 2022-03-23 12:23:11+03:00
#
#         Расширение штата по всем направлениям!
#
#
#
#
#
#
#
#
#
#
#
#
#         690
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 1 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# МТС объявляет о расширении набора специалистов всех бизнес-направлений, в том числе об открытии дополнительных вакансий для ИТ-экспертов
#
#
#
#
#
#
#
#
#
#
#
#
#
# В ИТ-направлении дополнительный набор сосредоточен в области разработки разного стека технологий (Java, .net, JS, Python, Golang, мобильная разработка), также востребованы DevOps-инженеры, аналитики, специалисты по Data Science, руководители ИТ-направлений. Вакансии открыты в командах, развивающих цифровые сервисы на основе Big Data, AI, облачной инфраструктуры и в других продуктовых подразделениях.  МТС также готова принять на работу новых сотрудников в сферах маркетинга и PR, финансов, HR и других.
# На работу в компании могут претендовать, в частности, специалисты в области продаж и развития технической инфраструктуры МТС. Компания также расширяет набор в службы клиентского сервиса (в том числе с возможностью удаленной работы) и в розничные салоны МТС.
#
# Читайте нас в Telegram
#
# 2022-01-18 10:14:53+03:00
#
#         Два центра цифрового образования создадут в Удмуртии в 2022 году
#
#
#
#
#
#
#
#
#
#
#
#
#         377
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 1 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# В 2022 году в Удмуртии планируют создать два центра цифрового образования детей «ИТ-куб». Как сообщает пресс-служба главы и правительства республики, они появятся в Сарапульском техникуме машиностроения и информационных технологий, а также в Глазовском технической колледже. Общий размер субсидии составляет 34,9 млн руб.
# В каждом «ИТ-кубе» смогут бесплатно заниматься до 400 детей. Обучение будет проводиться по трем обязательным и трем вариативным направлениям. В частности, в Сарапуле детей будут учить программированию на Python, разработке VR/AR-приложений, программированию роботов, системному администрированию, а также мобильной разработке и основам программирования на Java. В Глазове обучение пройдет по направлениям: «Программирование на Python», «Разработка VR/AR-приложений», «Программирование роботов», «Системное администрирование», а также «Мобильная разработка» и «Основы алгоритмики и логики».
#
# 2022-03-16 00:03:00+03:00
#
#         EPAM System и JetBrains приостанавливают деятельность
#
#
#
#
#
#
#
#
#
#
#
#
#         5K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 5 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Две крупные международные IT-компании, EPAM System и JetBrains, филиалы которых зарегистрированы в Санкт-Петербурге, сообщили о приостановке деятельности в связи со спецоперацией на Украине. Предприятия, занимающие десятки тысяч квадратных метров в офисных центрах Петербурга, проводят релокацию сотрудников, уводя их частично в другие страны. Аналитики считают, что громкие заявления сделаны под давлением и на эмоциях, а фактически компании заняли выжидательную позицию.
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Российский IT-сектор находится под санкциями с 2014 года, очередной пакет был введен в 2018 году. Многие игроки уже адаптировались к ним и продолжают работать в том числе с американскими и западноевропейскими заказчиками через другие страны, принимать подряды и работать по субподрядамФото: Игорь Иванко, Коммерсантъ
#
#
#
#
#
#
#
#
# Российский IT-сектор находится под санкциями с 2014 года, очередной пакет был введен в 2018 году. Многие игроки уже адаптировались к ним и продолжают работать в том числе с американскими и западноевропейскими заказчиками через другие страны, принимать подряды и работать по субподрядамФото: Игорь Иванко, Коммерсантъ
#
#
#
#
# Генеральный директор JetBrains Максим Шафиров сообщил в блоге, что компания приостанавливает продажи, исследования и разработки в России и Беларуси на неопределенный срок. По его словам, данное решение «было самым трудным из когда-либо принятых руководством».
# «На протяжении многих лет мы продолжали расширять наши офисы в других странах, открывая центры исследований и разработок в Санкт-Петербурге, Бостоне, Мюнхене, Амстердаме и других местах… Многие наши коллеги из России уже переехали в другие места, и мы их поддержим, как и всех наших сотрудников», — говорится в сообщении.
# JetBrains выпускает инструменты для разработки на языках Java, Kotlin, C#, F#, C++, Ruby, Python, PHP, JavaScript и других, а также средства командной работы. Компания была основана в 2000 году тремя российскими разработчиками, ее штаб-квартира находится в Праге. Основатели JetBrains — Сергей Дмитриев, Евгений Беляев и Валентин Кипятков. В 2000-х годах Евгений Беляев вышел из состава учредителей компании. Дмитриев и Кипятков — петербуржцы.
# Согласно данным «СПАРК-Интерфакс», в Санкт-Петербурге компания зарегистрирована как ООО «Интеллиджей Лабс» с численностью в 809 человек. Компания занимает в Lotos Tower на Приморском проспекте площадь в 22,3 тыс. кв. м. Выручка от продаж за 2020 год составила 5,6 млрд рублей, чистая прибыль — 448 млн рублей (выручка в 2019 — 5 млрд рублей, чистая прибыль — 343 млн рублей).
# Представитель JetBrains сообщил по телефону, что «офис пока работает», отказавшись от дальнейших комментариев.
# Еще один крупный разработчик программного обеспечения, EPAM, заявил о поддержке Украины и прекращении обслуживания клиентов в России. Компания пообещала «обеспечить переходную поддержку клиентов» и отметила, что не работает с российским правительством и полностью соблюдает санкции.
# EPAM Systems Inc. основана в 1993 году в Минске, является разработчиком заказного программного обеспечения для разных секторов экономики. Офисы компании расположены в 25 странах, а услуги предоставляются в более чем 40 странах. Сейчас штаб-квартира находится в Ньютауне, США. Выручка EPAM по итогам 2021 года, согласно данным компании, составила $3,75 млрд, что на 41,3% больше по сравнению с аналогичным периодом прошлого года.
# Согласно данным «СПАРК-Интерфакс», в Санкт-Петербурге у EPAM System четыре филиала: два крупных — в «Прогресс Сити» на набережной Черной речки, на 6 тыс. кв. м, и в «Мега Парке», на 11,2 тыс. кв. м, и два меньшей площадью — на Левашовском проспекте и в Певческом переулке. Заявленная численность в одном офисе — от 500 до 1000 человек. Управляющий «Мега Парка» Дмитрий Булаев сообщил «Ъ-СПб», что компания не подавала уведомления об окончании аренды площадей. Однако он не исключил этот процесс в связи с неопределенной ситуацией. В «Прогресс Сити» также сообщили, что компания не планирует закрывать офис.
# В свою очередь, в самом EPAM System на вопрос о закрытии филиалов ответили, что «не готовы сейчас предоставить комментарий по этой теме».
# Как ранее писал “Ъ”, более десяти IT-гигантов приостановили деятельность из-за спецоперации. Среди них, помимо названных выше: Avast, Cogent, Hitachi, Homa Games, IBM, Lumen, Microsoft, Miro, Norton Life Lock Inc., Oracle Corp, Panasonic, SAP.
# Около 14 компаний прекратили поставки своей продукции, в том числе программного обеспечения: AMD, Adobe (прекратила новые продажи продуктов и услуг), Apple (закрыла онлайн-продажи), Autodesk, Cisco Systems Inc., Dell, Ericsson, Intel, Nvidia, Nokia, Samsung, Siemens, Sony (PlayStation и программное обеспечение), Taiwan Semiconductor Manufacturing Company.
# Источник «Ъ-СПб» на рынке IT-услуг сообщил, что многие компании вывозят своих сотрудников в Грузию, Армению, на Кипр и в Чехию. Вывоз в первые две страны связан в том числе с тем, что не нужно делать визу, а при въезде в Армению достаточно только российского паспорта. При въезде в Чехию могут возникнуть проблемы с получением так называемой Blue Card — разрешения на пребывание и работу, выдаваемого иностранцу из-за пределов ЕС.
# Эксперты рынка сходятся во мнении, что отток разработчиков из России действительно есть, но он не принял массового характера, а те, кто уехал, заняли выжидательную позицию.
# «Уход игроков не позитивен для рынка, учитывая, что у нас отсутствует в большом количестве производство аппаратного и программного обеспечения. В любой стране есть определенные условия для приема сотрудников. Если компания сама организует рабочие места, то все проблемы, связанные с трудоустройством и выдачей трудовой визы, будь то в Чехии или Грузии, компания должна взять на себя. Но в любом случае понадобится время и большие деньги на оформление документов,— комментирует «Ъ-СПб» генеральный директор Telecom Daily Денис Кусков.— С другой стороны, уедут не все. Профессионалы будут востребованы, а государство заинтересовано в реальном создании IT-инфраструктуры в России, и уже есть определенная программа по поддержке индустрии».
# Гендиректор агентства «Рустелеком» Юрий Брюквин считает, что многие решения компаниями «принимаются сейчас либо под давлением, либо на эмоциях». Если компания покидает рынок, то это больше связано не с политическими событиями, а с экономическими: изменение курса рубля и логистики. Однако многие компании заинтересованы в российском рынке и заняли выжидательную позицию.
# «Российский IT-сектор находится под санкциями с 2014 года, очередной пакет был введен в 2018 году. Многие игроки уже адаптировались к ним и продолжают работать в том числе с американскими и западноевропейскими заказчиками через другие страны, принимать подряды и работать по субподрядам. Сейчас проблема есть, но она не такая критичная, как может показаться в связи с громкими заявлениями. Кроме того, принимаемые правительством меры более чем адекватны: это налоговый спецрежим, отсрочки, льготы, отсрочка от армии на три года и иные меры поддержки. Сейчас вводится еще один пакет по поддержке. Те, кто уехал, заняли выжидательную позицию. Когда спецоперация закончится, вернутся, потому что к этому времени стабилизируется ситуация с курсом, выстроится новая логистика. Например, новые транспортные коридоры из Казахстана через Китай в Россию, которые позволят ввозить санкционный товар»,— рассказал Юрий Брюквин.
# Алла Михеенко
#
# 2022-03-01 17:23:56+03:00
#
#         Porsche Macan в третьем поколении
#
#
#
#
#
#
#
#
#
#
#
#
#         24
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 3 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Первое поколение Macan появилось в 2014 году, второе в 2018 году, а в конце 2021 года компания объявила о выходе третьего поколения автомобилей данной модели.
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
# Предыдущая фотография
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
# Следующая фотография
#
#
#
# 1
#                 /
#                 4
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#                                                 Фото:
# ...
# На работу в компании могут претендовать, в частности, специалисты в области продаж и развития технической инфраструктуры МТС. Компания также расширяет набор в службы клиентского сервиса (в том числе с возможностью удаленной работы) и в розничные салоны МТС.
#
# Читайте нас в Telegram
#
# 2022-01-18 10:14:53+03:00
#
#         Два центра цифрового образования создадут в Удмуртии в 2022 году
#
#
#
#
#
#
#
#
#
#
#
#
#         377
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 1 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# В 2022 году в Удмуртии планируют создать два центра цифрового образования детей «ИТ-куб». Как сообщает пресс-служба главы и правительства республики, они появятся в Сарапульском техникуме машиностроения и информационных технологий, а также в Глазовском технической колледже. Общий размер субсидии составляет 34,9 млн руб.
# В каждом «ИТ-кубе» смогут бесплатно заниматься до 400 детей. Обучение будет проводиться по трем обязательным и трем вариативным направлениям. В частности, в Сарапуле детей будут учить программированию на Python, разработке VR/AR-приложений, программированию роботов, системному администрированию, а также мобильной разработке и основам программирования на Java. В Глазове обучение пройдет по направлениям: «Программирование на Python», «Разработка VR/AR-приложений», «Программирование роботов», «Системное администрирование», а также «Мобильная разработка» и «Основы алгоритмики и логики».
#
# 2022-03-16 00:03:00+03:00
#
#         EPAM System и JetBrains приостанавливают деятельность
#
#
#
#
#
#
#
#
#
#
#
#
#         5K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 5 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Две крупные международные IT-компании, EPAM System и JetBrains, филиалы которых зарегистрированы в Санкт-Петербурге, сообщили о приостановке деятельности в связи со спецоперацией на Украине. Предприятия, занимающие десятки тысяч квадратных метров в офисных центрах Петербурга, проводят релокацию сотрудников, уводя их частично в другие страны. Аналитики считают, что громкие заявления сделаны под давлением и на эмоциях, а фактически компании заняли выжидательную позицию.
#
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
#
#
#
#
#
#
#
# Российский IT-сектор находится под санкциями с 2014 года, очередной пакет был введен в 2018 году. Многие игроки уже адаптировались к ним и продолжают работать в том числе с американскими и западноевропейскими заказчиками через другие страны, принимать подряды и работать по субподрядамФото: Игорь Иванко, Коммерсантъ
#
#
#
#
#
#
#
#
# Российский IT-сектор находится под санкциями с 2014 года, очередной пакет был введен в 2018 году. Многие игроки уже адаптировались к ним и продолжают работать в том числе с американскими и западноевропейскими заказчиками через другие страны, принимать подряды и работать по субподрядамФото: Игорь Иванко, Коммерсантъ
#
#
#
#
# Генеральный директор JetBrains Максим Шафиров сообщил в блоге, что компания приостанавливает продажи, исследования и разработки в России и Беларуси на неопределенный срок. По его словам, данное решение «было самым трудным из когда-либо принятых руководством».
# «На протяжении многих лет мы продолжали расширять наши офисы в других странах, открывая центры исследований и разработок в Санкт-Петербурге, Бостоне, Мюнхене, Амстердаме и других местах… Многие наши коллеги из России уже переехали в другие места, и мы их поддержим, как и всех наших сотрудников», — говорится в сообщении.
# JetBrains выпускает инструменты для разработки на языках Java, Kotlin, C#, F#, C++, Ruby, Python, PHP, JavaScript и других, а также средства командной работы. Компания была основана в 2000 году тремя российскими разработчиками, ее штаб-квартира находится в Праге. Основатели JetBrains — Сергей Дмитриев, Евгений Беляев и Валентин Кипятков. В 2000-х годах Евгений Беляев вышел из состава учредителей компании. Дмитриев и Кипятков — петербуржцы.
# Согласно данным «СПАРК-Интерфакс», в Санкт-Петербурге компания зарегистрирована как ООО «Интеллиджей Лабс» с численностью в 809 человек. Компания занимает в Lotos Tower на Приморском проспекте площадь в 22,3 тыс. кв. м. Выручка от продаж за 2020 год составила 5,6 млрд рублей, чистая прибыль — 448 млн рублей (выручка в 2019 — 5 млрд рублей, чистая прибыль — 343 млн рублей).
# Представитель JetBrains сообщил по телефону, что «офис пока работает», отказавшись от дальнейших комментариев.
# Еще один крупный разработчик программного обеспечения, EPAM, заявил о поддержке Украины и прекращении обслуживания клиентов в России. Компания пообещала «обеспечить переходную поддержку клиентов» и отметила, что не работает с российским правительством и полностью соблюдает санкции.
# EPAM Systems Inc. основана в 1993 году в Минске, является разработчиком заказного программного обеспечения для разных секторов экономики. Офисы компании расположены в 25 странах, а услуги предоставляются в более чем 40 странах. Сейчас штаб-квартира находится в Ньютауне, США. Выручка EPAM по итогам 2021 года, согласно данным компании, составила $3,75 млрд, что на 41,3% больше по сравнению с аналогичным периодом прошлого года.
# Согласно данным «СПАРК-Интерфакс», в Санкт-Петербурге у EPAM System четыре филиала: два крупных — в «Прогресс Сити» на набережной Черной речки, на 6 тыс. кв. м, и в «Мега Парке», на 11,2 тыс. кв. м, и два меньшей площадью — на Левашовском проспекте и в Певческом переулке. Заявленная численность в одном офисе — от 500 до 1000 человек. Управляющий «Мега Парка» Дмитрий Булаев сообщил «Ъ-СПб», что компания не подавала уведомления об окончании аренды площадей. Однако он не исключил этот процесс в связи с неопределенной ситуацией. В «Прогресс Сити» также сообщили, что компания не планирует закрывать офис.
# В свою очередь, в самом EPAM System на вопрос о закрытии филиалов ответили, что «не готовы сейчас предоставить комментарий по этой теме».
# Как ранее писал “Ъ”, более десяти IT-гигантов приостановили деятельность из-за спецоперации. Среди них, помимо названных выше: Avast, Cogent, Hitachi, Homa Games, IBM, Lumen, Microsoft, Miro, Norton Life Lock Inc., Oracle Corp, Panasonic, SAP.
# Около 14 компаний прекратили поставки своей продукции, в том числе программного обеспечения: AMD, Adobe (прекратила новые продажи продуктов и услуг), Apple (закрыла онлайн-продажи), Autodesk, Cisco Systems Inc., Dell, Ericsson, Intel, Nvidia, Nokia, Samsung, Siemens, Sony (PlayStation и программное обеспечение), Taiwan Semiconductor Manufacturing Company.
# Источник «Ъ-СПб» на рынке IT-услуг сообщил, что многие компании вывозят своих сотрудников в Грузию, Армению, на Кипр и в Чехию. Вывоз в первые две страны связан в том числе с тем, что не нужно делать визу, а при въезде в Армению достаточно только российского паспорта. При въезде в Чехию могут возникнуть проблемы с получением так называемой Blue Card — разрешения на пребывание и работу, выдаваемого иностранцу из-за пределов ЕС.
# Эксперты рынка сходятся во мнении, что отток разработчиков из России действительно есть, но он не принял массового характера, а те, кто уехал, заняли выжидательную позицию.
# «Уход игроков не позитивен для рынка, учитывая, что у нас отсутствует в большом количестве производство аппаратного и программного обеспечения. В любой стране есть определенные условия для приема сотрудников. Если компания сама организует рабочие места, то все проблемы, связанные с трудоустройством и выдачей трудовой визы, будь то в Чехии или Грузии, компания должна взять на себя. Но в любом случае понадобится время и большие деньги на оформление документов,— комментирует «Ъ-СПб» генеральный директор Telecom Daily Денис Кусков.— С другой стороны, уедут не все. Профессионалы будут востребованы, а государство заинтересовано в реальном создании IT-инфраструктуры в России, и уже есть определенная программа по поддержке индустрии».
# Гендиректор агентства «Рустелеком» Юрий Брюквин считает, что многие решения компаниями «принимаются сейчас либо под давлением, либо на эмоциях». Если компания покидает рынок, то это больше связано не с политическими событиями, а с экономическими: изменение курса рубля и логистики. Однако многие компании заинтересованы в российском рынке и заняли выжидательную позицию.
# «Российский IT-сектор находится под санкциями с 2014 года, очередной пакет был введен в 2018 году. Многие игроки уже адаптировались к ним и продолжают работать в том числе с американскими и западноевропейскими заказчиками через другие страны, принимать подряды и работать по субподрядам. Сейчас проблема есть, но она не такая критичная, как может показаться в связи с громкими заявлениями. Кроме того, принимаемые правительством меры более чем адекватны: это налоговый спецрежим, отсрочки, льготы, отсрочка от армии на три года и иные меры поддержки. Сейчас вводится еще один пакет по поддержке. Те, кто уехал, заняли выжидательную позицию. Когда спецоперация закончится, вернутся, потому что к этому времени стабилизируется ситуация с курсом, выстроится новая логистика. Например, новые транспортные коридоры из Казахстана через Китай в Россию, которые позволят ввозить санкционный товар»,— рассказал Юрий Брюквин.
# Алла Михеенко
#
# 2022-03-01 17:23:56+03:00
#
#         Porsche Macan в третьем поколении
#
#
#
#
#
#
#
#
#
#
#
#
#         24
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 3 мин.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Первое поколение Macan появилось в 2014 году, второе в 2018 году, а в конце 2021 года компания объявила о выходе третьего поколения автомобилей данной модели.
#
#
#
#
#
# Выйти из полноэкранного режима
#
#
#
#
#
#
# Развернуть на весь экран
#
#
#
#
#
#
# Предыдущая фотография
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
#
#
# Следующая фотография
#
#
#
# 1
#                 /
#                 4
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#                                                 Фото:
#                                                                                             ООО «Порше Руссланд»
#
#
#
#
#
#
#
#
# Как отмечают в компании, Macan является второй по важности моделью для бренда Porsche в России после Cayenne. В том числе и потому, что согласно статистике 80% покупателей Macan являются новыми для бренда Porsche. То есть именно через эту модель «новички» впервые становятся обладателями, а впоследствии и поклонниками этого автомобильного бренда.
# Также доля женщин среди покупателей Macan за прошедшие годы постоянно растет и остается самой высокой среди всех модельных рядов Porsche. На китайском рынке, самом крупном рынке сбыта Macan, доля покупателей-женщин уже доходит почти до 60%.
# Быстрее, спортивнее, мощнее
# Третье поколение Macan представлено тремя моделями. Все они значительно мощнее, чем их предшественники. Самым спортивным вариантом является Macan GTS, выступающий в роли новой топ-модели успешной линейки SUV. Он оснащен 2,9-литровым двигателем V6 битурбо, который развивает 324 кВт (440 л. с.), что на 44 кВт (60 л. с.) больше, чем раньше. На разгон с места до 100 км/ч в комплектации с пакетом Sport Chrono уходит всего 4,3 секунды, а максимальная скорость составляет 272 км/ч.
# Модельный вариант Macan S также оснащен битурбированным V6 двигателем рабочим объемом 2,9 литра, который развивает мощность 280 кВт (380 л. с.). Это на 20 кВт (26 л. с.) больше, чем раньше. До «сотни» Macan S разгоняется за 4,6 секунды, а максимально — до 259 км/ч.
# Macan оснащается новым 4-цилиндровым рядным двигателем с турбонаддувом мощностью 195 кВт (265 л. с.). Этот модельный вариант выполняет стандартный разгон до 100 км/ч за 6,2 секунды, максимальная скорость составляет 232 км/ч.
# Все двигатели, как обычно, комбинируются с 7-ступенчатой коробкой передач с двумя сцеплениями Porsche Doppelkupplung (PDK) и с системой полного привода Porsche Traction Management (PTM).
# Акцент на спорт
# Проведя в Macan третьего поколения ряд изменений в дизайне, компания Porsche тем самым сделала акцент на спортивном характере своего компактного SUV. В новой модели по-новому оформлен передний бампер со вставкой в цвете кузова, что визуально увеличивает ширину и подчеркивает уверенное положение нового Macan на дороге. У нового GTS центральная часть переднего бампера, как и некоторые другие компоненты, выдержана в черном цвете. Задний диффузор теперь выполнен в подчеркнуто технологичном дизайне. Здесь, как и в передней части кузова, можно видеть новую 3D-структуру, которая в качестве опции может украшать также и боковые накладки. Светодиодные фары с системой Porsche Dynamic Light System (PDLS) и наружные зеркала SportDesign теперь входят в базовую комплектацию всех моделей.
# Также произошли изменения в салоне автомобиля. Модели Macan третьего поколения получили элегантную центральную консоль с сенсорной поверхностью — подобную той, что есть в автомобилях Cayenne. Управление многочисленными функциями и онлайн-сервисами осуществляется через 10,9-дюймовый сенсорный дисплей Full-HD системы Porsche Communication Management или же с помощью голосовых команд. Аналоговые часы в верхней части передней панели теперь являются частью базовой комплектации. А новое многофункциональное рулевое колесо и новое спортивное рулевое колесо GT заимствованы у 911.
# Больше цветов, чем у радуги
# Для нового Macan производитель предлагает 14 цветов кузова, в том числе новые цвета Papaya Metallic и Gentian Blue Metallic, а также Python Green для Macan GTS с пакетом GTS Sport. Услуги «Индивидуальный цвет» и «Цвет по выбору», предлагающиеся по программе Porsche Exclusive Manufaktur, значительно расширяют возможности индивидуализации.
# Также автомобили серийно оснащаются увеличенными колесными дисками: для Macan минимальный размер дисков составляет 19 дюймов, для Macan S — 20, а для Macan GTS — 21 дюйм. В целом программа колесных дисков дополнена семью новыми вариантами дизайна.
# В российских дилерских центрах все эти модели появились уже в конце 2021 года. На тот момент цены в России стартовали от 5 390 000 рублей на Macan, 6 490 000 рублей на Macan S и 7 490 000 рублей на Macan GTS, включая НДС. Очевидно, что после 24 февраля текущего года в условиях политической ситуации и экономической неопределенности стоимость на эти автомобили ожидают серьезные корректировки.

# %%
# запишем данные в датафрейм
kom_news = pd.DataFrame()
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text)
    time.sleep(0.3)
    date = pd.to_datetime(soup.find('time', class_='doc_header__publish_time').get('datetime'))
    title = soup.find('h1', class_='doc_header__name').text.strip()
    text = soup.find('div', class_='doc__body').text.strip().replace('\n', '')
    row = {'date': date, 'title': title, 'text': text}
    kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
kom_news
# Out:
#                        date  \
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-04-03 15:28:40+03:00
# 0 2022-04-06 21:09:05+03:00
# 0 2022-04-07 15:48:19+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-04-03 15:28:40+03:00
# 0 2022-04-06 21:09:05+03:00
# 0 2022-04-07 15:48:19+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-04-03 15:28:40+03:00
# 0 2022-04-06 21:09:05+03:00
# 0 2022-04-07 15:48:19+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-04-03 15:28:40+03:00
# 0 2022-04-06 21:09:05+03:00
# 0 2022-04-07 15:48:19+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-03-01 17:23:56+03:00
# 0 2022-01-21 13:23:20+03:00
# 0 2021-12-20 17:37:05+03:00
# 0 2022-04-03 15:28:40+03:00
# 0 2022-04-06 21:09:05+03:00
# 0 2022-04-07 15:48:19+03:00
# 0 2021-12-28 00:01:00+03:00
# 0 2022-03-23 12:23:11+03:00
# 0 2022-01-18 10:14:53+03:00
# 0 2022-03-16 00:03:00+03:00
# 0 2022-03-01 17:23:56+03:00
#
#                                                title  \
# 0                        Требуются продавцы. Срочно!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                                 Кадры идут учиться
# 0                   Разработчиков поставили на паузу
# 0            Самое главное о профессии геймдизайнера
# 0                                     Битва за кадры
# 0             Расширение штата по всем направлениям!
# 0  Два центра цифрового образования создадут в Уд...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0                  Porsche Macan в третьем поколении
# 0                        Требуются продавцы. Срочно!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                                 Кадры идут учиться
# 0                   Разработчиков поставили на паузу
# 0            Самое главное о профессии геймдизайнера
# 0                                     Битва за кадры
# 0             Расширение штата по всем направлениям!
# 0  Два центра цифрового образования создадут в Уд...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0                  Porsche Macan в третьем поколении
# 0                        Требуются продавцы. Срочно!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                                 Кадры идут учиться
# 0                   Разработчиков поставили на паузу
# 0            Самое главное о профессии геймдизайнера
# 0                                     Битва за кадры
# 0             Расширение штата по всем направлениям!
# 0  Два центра цифрового образования создадут в Уд...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0                  Porsche Macan в третьем поколении
# 0                        Требуются продавцы. Срочно!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                                 Кадры идут учиться
# 0                   Разработчиков поставили на паузу
# 0            Самое главное о профессии геймдизайнера
# 0                                     Битва за кадры
# 0             Расширение штата по всем направлениям!
# 0  Два центра цифрового образования создадут в Уд...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0                  Porsche Macan в третьем поколении
# 0                        Требуются продавцы. Срочно!
# 0  Нижегородские школьники смогут бесплатно пройт...
# 0                                 Кадры идут учиться
# 0                   Разработчиков поставили на паузу
# 0            Самое главное о профессии геймдизайнера
# 0                                     Битва за кадры
# 0             Расширение штата по всем направлениям!
# 0  Два центра цифрового образования создадут в Уд...
# 0  EPAM System и JetBrains приостанавливают деяте...
# 0                  Porsche Macan в третьем поколении
#
#                                                 text
# 0  3K\r    \r                1 мин.\r            ...
# 0  395\r    \r                1 мин.\r           ...
# 0  915\r    \r                3 мин.\r           ...
# 0  2K\r    \r                4 мин.\r            ...
# 0  4K\r    \r                5 мин.\r            ...
# 0  522\r    \r                8 мин.\r           ...
# 0  690\r    \r                1 мин.\r           ...
# 0  377\r    \r                1 мин.\r           ...
# 0  5K\r    \r                5 мин.\r            ...
# 0  24\r    \r                3 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  395\r    \r                1 мин.\r           ...
# 0  915\r    \r                3 мин.\r           ...
# 0  2K\r    \r                4 мин.\r            ...
# 0  4K\r    \r                5 мин.\r            ...
# 0  522\r    \r                8 мин.\r           ...
# 0  690\r    \r                1 мин.\r           ...
# 0  377\r    \r                1 мин.\r           ...
# 0  5K\r    \r                5 мин.\r            ...
# 0  24\r    \r                3 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  395\r    \r                1 мин.\r           ...
# 0  915\r    \r                3 мин.\r           ...
# 0  2K\r    \r                4 мин.\r            ...
# 0  4K\r    \r                5 мин.\r            ...
# 0  522\r    \r                8 мин.\r           ...
# 0  690\r    \r                1 мин.\r           ...
# 0  377\r    \r                1 мин.\r           ...
# 0  5K\r    \r                5 мин.\r            ...
# 0  24\r    \r                3 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  395\r    \r                1 мин.\r           ...
# 0  915\r    \r                3 мин.\r           ...
# 0  2K\r    \r                4 мин.\r            ...
# 0  4K\r    \r                5 мин.\r            ...
# 0  522\r    \r                8 мин.\r           ...
# 0  690\r    \r                1 мин.\r           ...
# 0  377\r    \r                1 мин.\r           ...
# 0  5K\r    \r                5 мин.\r            ...
# 0  24\r    \r                3 мин.\r            ...
# 0  3K\r    \r                1 мин.\r            ...
# 0  395\r    \r                1 мин.\r           ...
# 0  915\r    \r                3 мин.\r           ...
# 0  2K\r    \r                4 мин.\r            ...
# 0  4K\r    \r                5 мин.\r            ...
# 0  522\r    \r                8 мин.\r           ...
# 0  690\r    \r                1 мин.\r           ...
# 0  377\r    \r                1 мин.\r           ...
# 0  5K\r    \r                5 мин.\r            ...
# 0  24\r    \r                3 мин.\r            ...

# %%
# обернем в функцию 
def get_kom_news(links):
    kom_news = pd.DataFrame()
    for link in all_links:
        soup = BeautifulSoup(requests.get(link).text)
        time.sleep(0.3)
        date = pd.to_datetime(soup.find('time', class_='doc_header__publish_time').get('datetime'))
        title = soup.find('h1', class_='doc_header__name').text.strip()
        text = soup.find('div', class_='doc__body').text.strip().replace('\n', '')
        row = {'date': date, 'title': title, 'text': text}
        kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
    return kom_news.reset_index(drop=True)

get_kom_news(all_links)
# Out:
#                         date  \
# 0  2022-01-21 13:23:20+03:00
# 1  2021-12-20 17:37:05+03:00
# 2  2022-04-03 15:28:40+03:00
# 3  2022-04-06 21:09:05+03:00
# 4  2022-04-07 15:48:19+03:00
# 5  2021-12-28 00:01:00+03:00
# 6  2022-03-23 12:23:11+03:00
# 7  2022-01-18 10:14:53+03:00
# 8  2022-03-16 00:03:00+03:00
# 9  2022-03-01 17:23:56+03:00
# 10 2022-01-21 13:23:20+03:00
# 11 2021-12-20 17:37:05+03:00
# 12 2022-04-03 15:28:40+03:00
# 13 2022-04-06 21:09:05+03:00
# 14 2022-04-07 15:48:19+03:00
# 15 2021-12-28 00:01:00+03:00
# 16 2022-03-23 12:23:11+03:00
# 17 2022-01-18 10:14:53+03:00
# 18 2022-03-16 00:03:00+03:00
# 19 2022-03-01 17:23:56+03:00
# 20 2022-01-21 13:23:20+03:00
# 21 2021-12-20 17:37:05+03:00
# 22 2022-04-03 15:28:40+03:00
# 23 2022-04-06 21:09:05+03:00
# 24 2022-04-07 15:48:19+03:00
# 25 2021-12-28 00:01:00+03:00
# 26 2022-03-23 12:23:11+03:00
# 27 2022-01-18 10:14:53+03:00
# 28 2022-03-16 00:03:00+03:00
# 29 2022-03-01 17:23:56+03:00
# 30 2022-01-21 13:23:20+03:00
# 31 2021-12-20 17:37:05+03:00
# 32 2022-04-03 15:28:40+03:00
# 33 2022-04-06 21:09:05+03:00
# 34 2022-04-07 15:48:19+03:00
# 35 2021-12-28 00:01:00+03:00
# 36 2022-03-23 12:23:11+03:00
# 37 2022-01-18 10:14:53+03:00
# 38 2022-03-16 00:03:00+03:00
# 39 2022-03-01 17:23:56+03:00
# 40 2022-01-21 13:23:20+03:00
# 41 2021-12-20 17:37:05+03:00
# 42 2022-04-03 15:28:40+03:00
# 43 2022-04-06 21:09:05+03:00
# 44 2022-04-07 15:48:19+03:00
# 45 2021-12-28 00:01:00+03:00
# 46 2022-03-23 12:23:11+03:00
# 47 2022-01-18 10:14:53+03:00
# 48 2022-03-16 00:03:00+03:00
# 49 2022-03-01 17:23:56+03:00
#
#                                                 title  \
# 0                         Требуются продавцы. Срочно!
# 1   Нижегородские школьники смогут бесплатно пройт...
# 2                                  Кадры идут учиться
# 3                    Разработчиков поставили на паузу
# 4             Самое главное о профессии геймдизайнера
# 5                                      Битва за кадры
# 6              Расширение штата по всем направлениям!
# 7   Два центра цифрового образования создадут в Уд...
# 8   EPAM System и JetBrains приостанавливают деяте...
# 9                   Porsche Macan в третьем поколении
# 10                        Требуются продавцы. Срочно!
# 11  Нижегородские школьники смогут бесплатно пройт...
# 12                                 Кадры идут учиться
# 13                   Разработчиков поставили на паузу
# 14            Самое главное о профессии геймдизайнера
# 15                                     Битва за кадры
# 16             Расширение штата по всем направлениям!
# 17  Два центра цифрового образования создадут в Уд...
# 18  EPAM System и JetBrains приостанавливают деяте...
# 19                  Porsche Macan в третьем поколении
# 20                        Требуются продавцы. Срочно!
# 21  Нижегородские школьники смогут бесплатно пройт...
# 22                                 Кадры идут учиться
# 23                   Разработчиков поставили на паузу
# 24            Самое главное о профессии геймдизайнера
# 25                                     Битва за кадры
# 26             Расширение штата по всем направлениям!
# 27  Два центра цифрового образования создадут в Уд...
# 28  EPAM System и JetBrains приостанавливают деяте...
# 29                  Porsche Macan в третьем поколении
# 30                        Требуются продавцы. Срочно!
# 31  Нижегородские школьники смогут бесплатно пройт...
# 32                                 Кадры идут учиться
# 33                   Разработчиков поставили на паузу
# 34            Самое главное о профессии геймдизайнера
# 35                                     Битва за кадры
# 36             Расширение штата по всем направлениям!
# 37  Два центра цифрового образования создадут в Уд...
# 38  EPAM System и JetBrains приостанавливают деяте...
# 39                  Porsche Macan в третьем поколении
# 40                        Требуются продавцы. Срочно!
# 41  Нижегородские школьники смогут бесплатно пройт...
# 42                                 Кадры идут учиться
# 43                   Разработчиков поставили на паузу
# 44            Самое главное о профессии геймдизайнера
# 45                                     Битва за кадры
# 46             Расширение штата по всем направлениям!
# 47  Два центра цифрового образования создадут в Уд...
# 48  EPAM System и JetBrains приостанавливают деяте...
# 49                  Porsche Macan в третьем поколении
#
#                                                  text
# 0   3K\r    \r                1 мин.\r            ...
# 1   395\r    \r                1 мин.\r           ...
# 2   915\r    \r                3 мин.\r           ...
# 3   2K\r    \r                4 мин.\r            ...
# 4   4K\r    \r                5 мин.\r            ...
# 5   522\r    \r                8 мин.\r           ...
# 6   690\r    \r                1 мин.\r           ...
# 7   377\r    \r                1 мин.\r           ...
# 8   5K\r    \r                5 мин.\r            ...
# 9   24\r    \r                3 мин.\r            ...
# 10  3K\r    \r                1 мин.\r            ...
# 11  395\r    \r                1 мин.\r           ...
# 12  915\r    \r                3 мин.\r           ...
# 13  2K\r    \r                4 мин.\r            ...
# 14  4K\r    \r                5 мин.\r            ...
# 15  522\r    \r                8 мин.\r           ...
# 16  690\r    \r                1 мин.\r           ...
# 17  377\r    \r                1 мин.\r           ...
# 18  5K\r    \r                5 мин.\r            ...
# 19  24\r    \r                3 мин.\r            ...
# 20  3K\r    \r                1 мин.\r            ...
# 21  395\r    \r                1 мин.\r           ...
# 22  915\r    \r                3 мин.\r           ...
# 23  2K\r    \r                4 мин.\r            ...
# 24  4K\r    \r                5 мин.\r            ...
# 25  522\r    \r                8 мин.\r           ...
# 26  690\r    \r                1 мин.\r           ...
# 27  377\r    \r                1 мин.\r           ...
# 28  5K\r    \r                5 мин.\r            ...
# 29  24\r    \r                3 мин.\r            ...
# 30  3K\r    \r                1 мин.\r            ...
# 31  395\r    \r                1 мин.\r           ...
# 32  915\r    \r                3 мин.\r           ...
# 33  2K\r    \r                4 мин.\r            ...
# 34  4K\r    \r                5 мин.\r            ...
# 35  522\r    \r                8 мин.\r           ...
# 36  690\r    \r                1 мин.\r           ...
# 37  377\r    \r                1 мин.\r           ...
# 38  5K\r    \r                5 мин.\r            ...
# 39  24\r    \r                3 мин.\r            ...
# 40  3K\r    \r                1 мин.\r            ...
# 41  395\r    \r                1 мин.\r           ...
# 42  915\r    \r                3 мин.\r           ...
# 43  2K\r    \r                4 мин.\r            ...
# 44  4K\r    \r                5 мин.\r            ...
# 45  522\r    \r                8 мин.\r           ...
# 46  690\r    \r                1 мин.\r           ...
# 47  377\r    \r                1 мин.\r           ...
# 48  5K\r    \r                5 мин.\r            ...
# 49  24\r    \r                3 мин.\r            ...

# %% [markdown]
# # Спасибо за внимание! Буду рад ответить на ваши вопросы
# Форма ОС: https://forms.gle/y8xaFwJqtbFSjUeG8
