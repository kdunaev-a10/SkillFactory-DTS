# %% [markdown]
# ## 5. Знакомимся с данными: недвижимость

# %%
import pandas as pd
print(pd.__version__)
print(pd.__name__)

import numpy as np #импорт библиотеки для мат. вычислений
# Out:
# 1.4.3
# pandas

# %% [markdown]
# https://www.kaggle.com/dansbecker/melbourne-housing-snapshot

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
display(melb_data.loc[15, 'Price'])
display(melb_data.loc[90, 'Date'])
display(melb_data.loc[3521, 'Landsize'] / melb_data.loc[1690, 'Landsize'])
# Out:
# 1310000.0
# '10/09/2016'
# 2.7857142857142856

# %%
display(melb_data['index'])
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 13575    13575
# 13576    13576
# 13577    13577
# 13578    13578
# 13579    13579
# Name: index, Length: 13580, dtype: int64

# %% [markdown]
# ## 6. Исследование структуры DataFrame

# %%
display(melb_data.head())
display(melb_data.tail(7))
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
display(melb_data.shape)
melb_data.info()
# Out:
# (13580, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
for elm in ['Bedroom', 'Bathroom', 'Propertycount', 'YearBuilt' ]:
    melb_data[elm] = melb_data[elm].astype('int64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe(include=['int64']).count()
# Out:
# index            8
# Rooms            8
# Postcode         8
# Bedroom          8
# Bathroom         8
# Car              8
# YearBuilt        8
# Propertycount    8
# dtype: int64

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: Regionname, dtype: float64

# %%
melb_data['Regionname'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
melb_data['Type'].value_counts(normalize=True)*100
#melb_data['Type'].count()
# Out:
# h    69.580265
# u    22.216495
# t     8.203240
# Name: Type, dtype: float64

# %%
#melb_data[(melb_data['Type'] == 't')]['t'].sum()
#amazon_df[(amazon_df['brand_name'] == 'Hanky-Panky')]['review_count'].sum()
melb_data[(melb_data['Type'] == 't')]['Type'].count()/melb_data['Type'].count()*100
#ck_df['Type'].value_counts()
# Out:
# 8.203240058910161

# %% [markdown]
# ## 7. Статистические методы

# %%
print(melb_data['CouncilArea'].count())
print(melb_data['Price'].mean())
print(melb_data['Car'].max())
# Out:
# 12211
# 1075684.079455081
# 10

# %% [markdown]
#  риэлторская ставка для всех компаний за продажу недвижимости составляет 12%. Найдём общую прибыльность риэлторского бизнеса в Мельбурне

# %%
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))
# Out:
# Total income of real estate agencies: 1752934775.88

# %% [markdown]
# Отклонение медианы от среднего значения на 21% является довольно большим, и это повод задуматься над тем, чтобы исследовать признак на наличие аномалий.

# %%
landsize_median = melb_data['Landsize'].median() 
landsize_mean =  melb_data['Landsize'].mean()
print(landsize_median, landsize_mean)
print(abs(landsize_median - landsize_mean)/landsize_mean)
# Out:
# 440.0 558.4161266568483
# 0.21205713983546193

# %%
print(melb_data['Rooms'].mode())
print(melb_data['Regionname'].mode())
# Out:
# 0    3
# Name: Rooms, dtype: int64
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
print(melb_data['Propertycount'].max())
print(round(melb_data['Distance'].std()))
# Out:
# 21650
# 6

# %%
landsize_median = melb_data['BuildingArea'].median() 
landsize_mean =  melb_data['BuildingArea'].mean()
print(landsize_median, landsize_mean)
print(abs(landsize_median - landsize_mean)/landsize_mean*100)
# Out:
# 126.0 139.63397229013256
# 9.764079662364534

# %%
print(melb_data['Bedroom'].mode())
# Out:
# 0    3
# Name: Bedroom, dtype: int64

# %% [markdown]
# ## 8. Фильтрация данных в DataFrame

# %%
mask = melb_data['Price'] > 2000000
display(mask)
display(melb_data[mask].head())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# ...

# %%
melb_data[melb_data['Price'] > 2000000].head()
# Out:
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# 92    Cayzer  10/12/2016       3.3  ...    1     177.0         181.0
# 93      Greg  10/12/2016       3.3  ...    1     237.0         126.0
#
#     YearBuilt   CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
print(melb_data[melb_data['Rooms'] == 3].shape[0])
print(melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0])
print(melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0])
# Out:
# 5881
# 3
# 68

# %%
print( melb_data[melb_data['Type'] == 't']['Rooms'].max() )
# Out:
# 5

# %% [markdown]
# А теперь более сложный трюк: найдём медианную площадь здания у объектов, чья цена выше средней. Для того чтобы оградить наш код от нагромождений, предварительно создадим переменную со средней ценой:

# %%
mean_price = melb_data['Price'].mean()
print(mean_price)
print( melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median() )
# Out:
# 1075684.079455081
# 126.0

# %%
print( melb_data[melb_data['Bathroom'] == 0]['index'].shape[0] )
print(melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0])
print( melb_data[melb_data['BuildingArea'] == 0]['Price'].min() )

print(melb_data[((melb_data['Rooms'] > 5) ^ (melb_data['YearBuilt'] > 2015)) & (melb_data['Price'] < 1000000)]['Price'].mean())

print(melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].mode())
# Out:
# 34
# 5
# 412500.0
# 769238.6363636364
# 0    Northern Metropolitan
# Name: Regionname, dtype: object
